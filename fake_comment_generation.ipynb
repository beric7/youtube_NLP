# %%
# %matplotlib inline

# %%
# Test:
# Max length:
# 10
# 40
# Drop-out: 
# 0.4
# 0.7
# LSTM---->best performance
# RNN
# Compare performance between Decoder and AttnDecoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
path_to_final_project = "/content/drive/Shareddrives/Deep Learning Final Project/"
sys.path.append(path_to_final_project)
checkpoint_folder_path = "checkpoint/Reza/fake comment generation/max length 40/"
encoder_checkpoint_name = "encoder-best.pth"
decoder_checkpoint_name = "decoder-best.pth"

# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# *******************************************************************************
# **Author**: `Sean Robertson <https://github.com/spro/practical-pytorch>`_
#
# This is the third and final tutorial on doing "NLP From Scratch", where we
# write our own classes and functions to preprocess the data to do our NLP
# modeling tasks. We hope after you complete this tutorial that you'll proceed to
# learn how `torchtext` can handle much of this preprocessing for you in the
# three tutorials immediately following this one.
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ::
#
#     [KEY: > input, = target, < output]
#
#     > il est en train de peindre un tableau .
#     = he is painting a picture .
#     < he is painting a picture .
#
#     > pourquoi ne pas essayer ce vin delicieux ?
#     = why not try that delicious wine ?
#     < why not try that delicious wine ?
#
#     > elle n est pas poete mais romanciere .
#     = she is not a poet but a novelist .
#     < she not not a poet but a novelist .
#
#     > vous etes trop maigre .
#     = you re too skinny .
#     < you re all alone .
#
# ... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the `sequence
# to sequence network <https://arxiv.org/abs/1409.3215>`__, in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# To improve upon this model we'll use an `attention
# mechanism <https://arxiv.org/abs/1409.0473>`__, which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -  https://pytorch.org/ For installation instructions
# -  :doc:`/beginner/deep_learning_60min_blitz` to get started with PyTorch in general
# -  :doc:`/beginner/pytorch_with_examples` for a wide and deep overview
# -  :doc:`/beginner/former_torchies_tutorial` if you are former Lua Torch user
#
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <https://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <https://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <https://arxiv.org/abs/1506.05869>`__
#
# You will also find the previous tutorials on
# :doc:`/intermediate/char_rnn_classification_tutorial`
# and :doc:`/intermediate/char_rnn_generation_tutorial`
# helpful as those concepts are very similar to the Encoder and Decoder
# models, respectively.
#
# And for more, read the papers that introduced these topics:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <https://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <https://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <https://arxiv.org/abs/1506.05869>`__
#
#
# **Requirements**

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# `This question on Open Data Stack
# Exchange <https://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages>`__
# pointed me to the open translation site https://tatoeba.org/ which has
# downloads available at https://tatoeba.org/eng/downloads - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: https://www.manythings.org/anki/
#
# The English to French pairs are too big to include in the repo, so
# download to ``data/eng-fra.txt`` before continuing. The file is a tab
# separated list of translation pairs:
#
# ::
#
#     I am cold.    J'ai froid.
#
# .. Note::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/data.zip>`_
#    and extract it to the current directory.

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# .. figure:: /_static/img/seq-seq-images/word-encoding.png
#    :alt:

# %% [markdown]
# We'll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called ``Lang`` which has word → index (``word2index``) and index → word
# (``index2word``) dictionaries, as well as a count of each word
# ``word2count`` to use to later replace rare words.

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we'll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we're filtering to sentences that translate to
# the form "I am" or "He is" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 40

def filterPair(p):
  return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -  Read text file and split into lines, split lines into pairs
# -  Normalize text, filter by length and content
# -  Make word lists from sentences in pairs

# %%
def sentences_preprocessing(panda_dataset, header_com, header_reply):

  # all this would do is remove rows if elements were missing in any of the columns. 
  panda_dataset = panda_dataset.dropna()

  #remove \r (this is where you are running into vocabulary problems.)
  panda_dataset = panda_dataset.replace(to_replace=r'\r', value='', regex=True)

  #remove \n (this is where you are running into vocabulary problems.)
  panda_dataset = panda_dataset.replace(to_replace='\n', value='', regex=True)

  #convert pandas to list
  list_dataset = np.transpose([panda_dataset[header_com],panda_dataset[header_reply]]).tolist()
  return list_dataset, panda_dataset

# %%
import pandas as pd
import numpy as np

TRAINING_CSV = 'Childish Gambino - This Is America (Official Video)_refined.csv'
VALIDATION_CSV = 'Childish Gambino - This Is America (Official Video)_validation_comments_top_n.csv'

# %%
training_raw_data = pd.read_csv(path_to_final_project+'data/'+TRAINING_CSV, error_bad_lines=False, encoding='utf-8-sig')
training_raw_data.head()
# Out:
#                                     no_space_comment  ... first_2_words_in_no_space_comment
# 0  donald glover jack of all trades , master of a...  ...                     donald glover
# 1  no one \r \r \r \r \r \r\r\r\n \r \r \r \r \r ...  ...                            no one
# 2  me brings bulletproof shield to school \r \r \...  ...                         me brings
# 3                     2020 someone ? very niceee ! !  ...                      2020 someone
# 4  childish gambino 'shoots someone' " this is am...  ...                  childish gambino
#
# [5 rows x 6 columns]

# %%
test_raw_data = pd.read_csv(path_to_final_project+'data/'+VALIDATION_CSV, error_bad_lines=False, encoding='utf-8-sig')
test_raw_data.head()
# Out:
#                                   Validation Comment  ... first_2_words_in_Validation Comment
# 0  at the current state , we can do anything in a...  ...                              at the
# 1  i miss donald as troy in community when he lef...  ...                              i miss
# 2       when he said " this is america " i felt that  ...                             when he
# 3       love him or hate him , hes telling the truth  ...                            love him
# 4  when the church people were singing i heard " ...  ...                            when the
#
# [5 rows x 4 columns]

# %%
training_data, df_training = sentences_preprocessing(training_raw_data, 'first_2_keywords_in_no_space_comment' , 'no_space_comment')
# training_data, df_training = sentences_preprocessing(training_raw_data, 'first_2_words_in_no_space_comment' , 'no_space_comment')
print(np.shape(training_data))
df_training.head()
# Out:
# (5736, 2)
#                                     no_space_comment  ... first_2_words_in_no_space_comment
# 0  donald glover jack of all trades , master of a...  ...                     donald glover
# 1  no one             childish gambinos spine rig...  ...                            no one
# 2  me brings bulletproof shield to school       t...  ...                         me brings
# 3                     2020 someone ? very niceee ! !  ...                      2020 someone
# 4  childish gambino 'shoots someone' " this is am...  ...                  childish gambino
#
# [5 rows x 6 columns]

# %%
test_data, df_test = sentences_preprocessing(test_raw_data, 'first_2_keywords_in_Validation Comment', 'Validation Comment')
# test_data, df_test = sentences_preprocessing(test_raw_data, 'first_2_words_in_Validation Comment', 'Validation Comment')
print(np.shape(test_data))
df_test.head()
# Out:
# (340, 2)
#                                   Validation Comment  ... first_2_words_in_Validation Comment
# 0  at the current state , we can do anything in a...  ...                              at the
# 1  i miss donald as troy in community when he lef...  ...                              i miss
# 2       when he said " this is america " i felt that  ...                             when he
# 3       love him or hate him , hes telling the truth  ...                            love him
# 4  when the church people were singing i heard " ...  ...                            when the
#
# [5 rows x 4 columns]

# %%
  # #add space between words and some character
  # panda_dataset = panda_dataset.replace(to_replace=r':', value=':', regex=True) 
  # panda_dataset = panda_dataset.replace(to_replace=r',', value=' ,', regex=True) 
  # panda_dataset = panda_dataset.replace(to_replace=r'\'', value=' \'', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\`', value=' \`', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\.', value=' .', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\(', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\)', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\[', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\]', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\{', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\}', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\?', value=' ?', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\!', value=' !', regex=True)
  # #remove asteriks
  # panda_dataset = panda_dataset.replace(to_replace=r'\*', value='', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace='\n', value=' \n ', regex=True)
  # #remove some repetitive spaces 
  # space = ' '
  # for i in range(10):
  #   space +=' '
  #   panda_dataset = panda_dataset.replace(to_replace=space, value=' ', regex=True) #add space after \n

# %%
# This gets me the data trimmed so that I can create the vocabulary comparison
def prepare_data_vocab(comment_reply, reverse=False):
    pairs = filterPairs(comment_reply) 
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    input_sentence = [i[0] for i in pairs]
    output_sentence = [i[1] for i in pairs]

    return input_sentence, output_sentence

# %%
print("########### Training Set ###########")
input_sentence, output_sentence = prepare_data_vocab(training_data, True)

print("\n","########### Test Set ###########")
test_input_sentence, test_output_sentence = prepare_data_vocab(test_data, True)
# Out:
# ########### Training Set ###########
# Trimmed to 4958 sentence pairs
# Counting words...
#
#  ########### Test Set ###########
# Trimmed to 339 sentence pairs
# Counting words...

# %%
import itertools
def unique(list1): 
      
    # insert the list to the set 
    list_set = set(list1) 
    # convert the set to the list 
    unique_list = (list(list_set))
    
    return unique_list

def top_n_words(input_sentence):

    words = []
    for comment in input_sentence:
        temp = comment.split()
        words.append(temp)
                     
    unique_word_list = list(itertools.chain(*words))
    
    unique_word_list = unique(unique_word_list)
    
    return unique_word_list

# %%
print("########### Training Set ###########")
unique_word_list_train = top_n_words(input_sentence)
print(len(unique_word_list_train))
print(unique_word_list_train)
print("\n","########### Test Set ###########")
unique_word_list_test = top_n_words(test_input_sentence)
print(len(unique_word_list_test))
print(unique_word_list_test)
# Out:
# ########### Training Set ###########
# 2166
# ['modified', 'ill', 'whites', 'floy', 'mad', 'sang', 'largest', 'releases', 'become', 'starting', 'miserable', 'sms', 'running', '699k', 'part', 'mental', 'sublime', 'neighbors', 'twist-', 'white_circle', 'notices', 'symbolizes', '30', 'yknow', "ain't", 'theme', "one's", 'inform', 'crummy', 'fire', "karen's", 'internet', '680', "african-american's", 'hard', 'two', 'main', '705k', 'eyes', 'hello', 'papulince', 'es', 'theyre', 'heal', 'intro', 'cycle', 'ago', 'amo', 'loco', 'soo', 'notice', '23', 'joe', 'worse', 'humans', 'economy', 'cried', 'clue', 'iq', 'couldnt', 'programming', 'ever', 'block', 'folded_hands', 'lady', 'happy', 'something', 'believe', 'nome', 'sir', 'understands', 'prediction', '706k', 'recoil', 'care', 'darkest', '40', 'currently', 'team', 'man', 'discusting', 'vibe', 'scared', 'foreshadowing', 'system', 'mcdonalds', 'average', 'motherfuckas', 'like', 'revisit', 'guess', 'australian', 'speaks', 'vpn', 'therefore', '01', 'btw', 'heavy', 'shocked', 'niggas', 'shouldnt', 'clover', 'face_blowing_a_kiss', 'waste', 'allowed', 'teammate', 'reached', 'wang', 'red_heart_selector', 'masterpiece', 'kyle', 'wer', 'crazy', 'amazing', 'peace', 'favorite', 'gambino', 'fantasy', 'georges', 'officially', 'ray', 'serious', 'loudly_crying_face', 'plays', 'covid', 'perfect', 'matters', 'inspired', 'person_gesturing_ok', 'marsh', 'son', 'hundred', 'sick', 'walking', 'ge', 'susan', 'songs', 'sum', 'stay', 'money', 'country', 'hmm', 'hesitate', 'fuckers', 'among', 'waiting', 'cringe', 'suppose', 'vid', 'police', 'became', '720k', 'plug', 'clicked', 'dirty', 'happened', '2020', 'spiderman', 'breonna', 'profitn', 'blunt', 'nul', 'racists', 'free', 'cold', 'kids', '10m', 'quite', 'grief', 'african', 'blue', 'protest', '33', 'crystal', 'printed', 'atlanta', 'criminal', 'eso', 'scientists', 'north', 'dark', 'savage', 'biden', 'point', 'last', 'purpose', 'imagined', 'confused', 'pis', 'instead', 'ironically', 'mass', 'arrest', 'dam', 'stuff', 'cool', 'broken_heart', 'protests', 'looking', 'cad', 'truly', 'described', 'lit', 'directed', 'underprivileged', 'flying', 'chilling', 'brown', 'exited', 'fiction', 'amrica', 'independence', '699', 'legend', 'heartbreaking', 'inside', '25', 'giy', 'injured', 'clown_face', 'million', 'kid', 'king', '2years', '17', 'gonna', 'poor', 'left-facing_fist', 'conveyed', "world's", 'uu', 'accurately', 'putting', 'wouldnt', 'merica', '707', 'lots', 'dissed', 'dance', 'heart_suit_selector', 'karens', 'early', 'ouugjhjjsdj', 'prime', 'lyrics', 'easily', 'innocent', 'um', 'trippin', 'triping', 'absolutely', 'light_skin_tone', 'offended', '1b', 'banned', 'democrats', 'thumbs_up', 'idea', 'struggle', 'kocak', 'giving', 'defintely', '704m', '28', 'literally', 'omg', 'tripping', 'expressionless_face', 'damm', 'mind', 'beautiful', 'always', 'makes', '95%', 'sitting', 'joker', 'meaning', 'lets', 'disagree', 'front', 'strong', '8', 'isnt', 'person', '80%', 'aksking', 'graphic', 'knock', 'awesome', 'community', 'united', 'tenet', 'brazilian', 'focken', 'aside', 'alguien', 'heard', 'buenara', 'scariest', 'party', 'eggs', 'obama', 'latino', 'holy-', 'america', 'director', 'slaves', 'cars', 'p', 'normal', 'hell', 'flushed_face', 'problematic', 'policeman', 'replace', '19', 'nefarious', 'pile_of_poo', 'nv', 'unironically', 'back', 'play', 'feel', 'ww3', 'afraid', 'dark_skin_tone', 'fast', 'huh', '0%', 'rascist', 'japan', 'wea', '9cm', 'brazil', 'rt', 'aim', 'winsconsin', 'meh', 'exactly', 'ad', '99%', 'fake', 'china', 'algum', 'peacefully', 'hi', 'raised_fist', "i'm", '#icantbreathe', 'fortnite', 'bop', '53', 'mom', 'offense', 'm6ux8dfmbb;37', 'destruction', 'describes', 'stupid', 'site', 'end', 'letting', 'zoom', 'justhis', 'haha', "he's", 'brings', 'beaming_face_with_smiling_eyes', 'childish', 'no-one', '710k', 'phillipines', 'diferent', 'dudes', 'harmed', 'relevancy', 'baba', 'dumb', 'suxxx', 'gringos', 'peoplr', 'state', 'ship', 'relieved_face', 'offensively', 'project', 'probably', 'class', 'corona', 'suck', 'outfits', ...
#
#  ########### Test Set ###########
# 405
# ['american', 'whites', 'yo', 'donald', 'girlfriend', 'away', 'iran', 'amerca', 'jack', 'dream', 'homecoming', 'occurred', 'talk', 'kinda', 'got', 'facts', 'reason', "ain't", 'fire', 'virus', 'hard', 'comes', 'surprised', 'days', 'two', 'found', 'opinion', 'abed', 'idk', 'flex', 'dad', 'messy', 'hello', '1', 'moral', 'told', 'intro', 'maybe', 'young', 'notice', 'listening', 'mean', 'cried', 'playing', 'stop', 'good', 'filming', 'cant', 'happy', 'smoking', 'believe', 'third', '700m', 'darkest', 'met', 'dope', 'man', 'legit', 'remix', 'represent', 'like', 'almost', 'well', 'second', 'fuckin', 'speaks', 'vpn', 'proof', 'sooo', 'said', 'take', 'describing', 'expecting', 'anytime', 'long', 'white', 'concept', 'thank', 'everyone', 'current', 'interesting', 'masterpiece', 'true', 'brothers', 'crazy', 'wonder', 'amazing', 'choreography', 'creative', 'pls', 'kitty', 'suicide', 'hella', 'anyone', 'serious', 'start', 'plays', 'perfect', 'first', 'os', 'open', 'everything', 'diss', 'petition', 'see', 'commentary', 'time', 'knew', 'police', 'maga', 'want', 'subscribe', ';', 'plug', 'gun', 'watch', '2020', 'go', 'sad', 'wow', 'know', 'free', 'kids', 'many', 'dislikes', 'disses', 'call', 'noticed', 'song', 'yeah', 'billion', 'real', 'day', 'u', 'recommendation', 'dark', 'gives', 'views', 'really', 'posture', 'matter', 'glad', 'episode', 'nigga', 'memes', 'truth', 'miss', 'else', 'cool', 'imagine', "can't", 'sudden', 'flying', 'im', 'amrica', 'legend', 'dislike', 'trump', 'hey', 'fitting', 'blows', 'w', 'dancing', 'racist', 'left', 'asians', 'gonna', 'j', 'gotta', 'acted', 'uu', 'facial', 'disappointing', 'look', 'russia', 'saw', 'wear', 'dance', 'whos', 'wearing', 'hum', 'needs', 'relevant', 'miracle', '1b', 'racism', 'still', 'wants', 'goes', 'omg', '5', 'dont', 'mind', 'beautiful', 'always', 'though', 'makes', 'beginning', 'yup', 'pretty', "'murica", 'lets', 'people', 'recommendations', 'comments', '8', 'please', 'lol', 'person', 'funny', 'love', 'touch', 'community', 'obsessed', 'heard', 'sorry', 'planet', 'things', 'forever', 'wrong', 'party', 'background', 'america', 'telling', 'videos', "america's", 'cars', 'rappers', 'hell', 'much', '2018', 'hurts', 'spider-man', 'listens', 'replace', 'predicted', 'ask', 'comment', 'better', 'someone', 'bunch', 'play', 'brain', 'feel', 'lando', 'wait', 'hidden', 'message', 'hear', 'years', 'puts', 'use', 'aged', 'thats', 'predict', 'reaction', 'god', 'china', 'iconic', 'embarrassed', 'movie', "i'm", 'war', 'social', 'pick', 'describes', 'europe', 'stupid', 'americahello', 'went', 'find', 'yep', 'paper', "he's", 'seems', 'riot', 'damn', "let's", 'looting', 'childish', 'dudes', 'one', 'hitting', 'mask', 'canada', 'tea', 'state', 'story', 'finest', 'creation', 'watched', 'lmaoo', "that's", 'make', 'ft', 'screams', 'minute', 'lives', 'future', 'fucking', 'anybody', 'gon', 'guys', 'send', 'fucked', 'changed', 'understand', 'check', 'listen', "he'll", 'fbe', 'youtube', 'depression', 'hes', 'ee', 'likes', 'come', 'deep', 'patrick', 'cup', 'kind', 'meme', 'church', 'troy', 'came', 'feels', 'representation', 'karen', 'world', 'canadians', 'genius', 'n', 'watching', 'started', 'everytime', '2', 'remember', 'rlly', 'black', 'pumped', 'movements', 'bet', 'wish', 'coming', 'kill', 'fuck', 'since', 'reminds', 'dang', 'sadly', 'hearing', 'realize', 'trades', 'headphones', 'glover', 'everyday', 'thought', 'never', 'aaron', 'whole', 'year', 'must', 'used', 'shit', 'friends', 'didnt', 'think', 'video', 'guy', 'going', 'music', "there's", 'murder', 'right', 'flyingkitty', 'face', 'worst', 'lost', 'underrated', 'based', 'us', 'run', 'moved', 'songbecause', 'simply', 'scarily', 'way', 'hate', 'remembers', 'bts', 'after', 'saying', '2021', 'decade', 'shut', 'tune', 'another', 'even', 'taken', 'dude', 'regret', 'best', 'africa', 'marshall', 'actually']

# %%
import csv
csv_vocab_validation = 'vocabulary_validation.csv'
save_csv_location = path_to_final_project+'data/'+csv_vocab_validation
val_comment_vocab_check = []
with open(save_csv_location, 'w', newline='', encoding='utf-8-sig') as csvfile:
    fieldnames = ['Validation Comment', 'Validation Reply']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for sentence in test_input_sentence:
        individual_words = sentence.split()
        # print(individual_words)
        if all(item in unique_word_list_train for item in individual_words):
            val_comment_vocab_check.append(sentence)
            writer.writerow({'Validation Comment': sentence, 'Validation Reply': 'no reply'})
        else:
            continue
        
# print(val_comment_vocab_check)
print('here')
# Out:
# here

# %%
test_raw_data = pd.read_csv(save_csv_location, error_bad_lines=False, encoding='utf-8-sig') #----> change "data.csv" when the test set is ready
test_raw_data.head()
# Out:
#   Validation Comment Validation Reply
# 0      current state         no reply
# 1        miss donald         no reply
# 2       said america         no reply
# 3          love hate         no reply
# 4      church people         no reply

# %%
test_data, df_test = sentences_preprocessing(test_raw_data, 'Validation Comment', 'Validation Reply')
print(np.shape(test_data))
df_test.head()
# Out:
# (261, 2)
#   Validation Comment Validation Reply
# 0      current state         no reply
# 1        miss donald         no reply
# 2       said america         no reply
# 3          love hate         no reply
# 4      church people         no reply

# %%
def prepare_Data(comment_reply, reverse=False):
    pairs = filterPairs(comment_reply) 
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    input_sentence = Lang("comment")
    
    output_sentence = Lang("reply")

    for pair in pairs:
        # print(count)
        input_sentence.addSentence(pair[0])
        output_sentence.addSentence(pair[1])

    print("Counted words:")
    print(input_sentence.name, input_sentence.n_words)
    print(output_sentence.name, output_sentence.n_words)
    return input_sentence, output_sentence, pairs

    return input_sentence, output_sentence, pairs

print("########### Training Set ###########")
input_sentence, output_sentence, pairs = prepare_Data(training_data, True)
print(random.choice(pairs))
print("\n","########### Test Set ###########")
test_input_sentence, test_output_sentence, test_pairs = prepare_Data(test_data, True)
print(random.choice(test_pairs))
# Out:
# ########### Training Set ###########
# Trimmed to 4958 sentence pairs
# Counting words...
# Counted words:
# comment 2168
# reply 5418
# ['asian street', 'an asian on the street       nobody       karens be like . . .']
#
#  ########### Test Set ###########
# Trimmed to 261 sentence pairs
# Counting words...
# Counted words:
# comment 295
# reply 4
# ['always come', 'no reply']

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A `Sequence to Sequence network <https://arxiv.org/abs/1409.3215>`__, or
# seq2seq network, or `Encoder Decoder
# network <https://arxiv.org/pdf/1406.1078v3.pdf>`__, is a model
# consisting of two RNNs called the encoder and decoder. The encoder reads
# an input sequence and outputs a single vector, and the decoder reads
# that vector to produce an output sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence "Je ne suis pas le chat noir" → "I am not the
# black cat". Most of the words in the input sentence have a direct
# translation in the output sentence, but are in slightly different
# orders, e.g. "chat noir" and "black cat". Because of the "ne/pas"
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the "meaning" of the input sequence into a single
# vector — a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# .. figure:: /_static/img/seq-seq-images/encoder-network.png
#    :alt:

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        # self.gru = nn.GRU(hidden_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        # self.rnn = nn.RNN(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# The Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ^^^^^^^^^^^^^^
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string ``<SOS>``
# token, and the first hidden state is the context vector (the encoder's
# last hidden state).
#
# .. figure:: /_static/img/seq-seq-images/decoder-network.png
#    :alt:

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        # self.gru = nn.GRU(hidden_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        # self.rnn = nn.RNN(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we'll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# ^^^^^^^^^^^^^^^^^
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# .. figure:: https://i.imgur.com/1152PYf.png
#    :alt:
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# .. figure:: /_static/img/seq-seq-images/attention-decoder-network.png
#    :alt:

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        # self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size)
        # self.rnn = nn.RNN(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>There are other forms of attention that work around the length
#   limitation by using a relative position approach. Read about "local
#   attention" in `Effective Approaches to Attention-based Neural Machine
#   Translation <https://arxiv.org/abs/1508.04025>`__.</p></div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_sentence, pair[0])
    target_tensor = tensorFromSentence(output_sentence, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# "Teacher forcing" is the concept of using the real target outputs as
# each next input, instead of using the decoder's guess as the next input.
# Using teacher forcing causes it to converge faster but `when the trained
# network is exploited, it may exhibit
# instability <http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf>`__.
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation -
# intuitively it has learned to represent the output grammar and can "pick
# up" the meaning once the teacher tells it the first few words, but it
# has not properly learned how to create the sentence from the translation
# in the first place.
#
# Because of the freedom PyTorch's autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# ``teacher_forcing_ratio`` up to use more of it.

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)   
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -  Start a timer
# -  Initialize optimizers and criterion
# -  Create set of training pairs
# -  Start empty losses array for plotting
#
# Then we call ``train`` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
    best_loss = 1e9

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()
    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        #saving the models
        if loss <best_loss:
          best_loss = loss
          torch.save(encoder.state_dict(), path_to_final_project + checkpoint_folder_path + encoder_checkpoint_name)
          torch.save(decoder.state_dict(), path_to_final_project + checkpoint_folder_path + decoder_checkpoint_name)

        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            evaluateRandomly(encoder, decoder,pairs,n=2)


        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ----------------
#
# Plotting is done with matplotlib, using the array of loss values
# ``plot_losses`` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_sentence, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_sentence.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, pairs, seed=5, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we'll get some
# reasonable results.
#
# .. Note::
#    If you run this notebook you can train, interrupt the kernel,
#    evaluate, and continue training later. Comment out the lines where the
#    encoder and decoder are initialized and run ``trainIters`` again.

# %%
#--------> IMPORTATNT NOTE: running this block will re-write the checkpoints. Make sure to get a backup before uncommenting and training

hidden_size = 256
encoder1 = EncoderRNN(input_sentence.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_sentence.n_words, dropout_p=0.1).to(device)
# attn_decoder1 = DecoderRNN(hidden_size, output_sentence.n_words).to(device)

trainIters(encoder1, attn_decoder1, 75000, print_every=500)
# Out:
# 0m 18s (- 46m 27s) (500 0%) 4.8039
# > raised_fist raised_fist
# = raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone       black lines matter red_heart_selector red_heart_selector
# < i
#
# > lives dont
# = all lives dont matter until black lives matter raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist light_skin_tone raised_fist medium_light_skin_tone
# < i
#
# 0m 31s (- 38m 45s) (1000 1%) 4.7716
# > song aged
# = this song aged better than ever
# < this song this song this song is
#
# > never listened
# = i never listened to this song when it first came out . listening to this actually is a good representation of america . i swear as soon as i turn 18 im moving to canada
# < this song this song this song this song this song <EOS>
#
# 0m 44s (- 36m 14s) (1500 2%) 4.9889
# > july nothing
# = i am here in july but nothing has changed . this is america
# < this is the is <EOS>
#
# > america
# = this is america ?       no !       this is pile_of_poo pile_of_poo backhand_index_pointing_left
# < this is the is <EOS>
#
# 0m 56s (- 34m 29s) (2000 2%) 4.7959
# > fuck dances
# = who the fuck dances like that
# < i is the is the <EOS>
#
# > wait real
# = wait . . . did he for real kill those people ;---;
# < i is the is the in the in the <EOS>
#
# 1m 9s (- 33m 41s) (2500 3%) 4.7211
# > boo music
# = boo this music is not cool in 2020 please subscribe to the two tryhards
# < this is is <EOS>
#
# > i'm going
# = i'm going to tell my children that this is justin beiber
# < this is is <EOS>
#
# 1m 22s (- 32m 58s) (3000 4%) 4.5295
# > song diferent
# = this song has such a diferent feel now , holly shit
# < this is america this is america <EOS>
#
# > troy darkest
# = troy in the darkest timeline .
# < this is america this is america <EOS>
#
# 1m 35s (- 32m 30s) (3500 4%) 4.6894
# > gambino predicted
# = gambino predicted 2020 .       rioting , while hollywood trying to distract us .       cars empty , while everyone is being locked indoors .
# < this song is this song <EOS>
#
# > music
# = this is not music
# < this song this song is this song <EOS>
#
# 1m 48s (- 32m 3s) (4000 5%) 4.4416
# > blacks nv
# = blacks will nv get the same rights as whites and that's fine with me
# < i hate this song <EOS>
#
# > 700 000
# = 700 . 000 killed , nobody bats an eye . 1 man killed , and everyone loses their mind !
# < i hate this song <EOS>
#
# 2m 1s (- 31m 40s) (4500 6%) 4.5427
# > black live
# = black live matter raised_fist dark_skin_tone raised_fist light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_light_skin_tone like guys ( ) heart_suit
# < this is america . <EOS>
#
# > offense american
# = no offense to all the american but i used to want to live there but its to unsafe and shit for me to survive
# < this is america .
#
# 2m 14s (- 31m 20s) (5000 6%) 4.5672
# > wish one
# = i wish i did one thing as well as donald glover does everything .
# < this song this song this song <EOS>
#
# > like stating
# = i don't like stating conspiracies , but that the people at 2 28 are wearing masks seems very interesting to me .
# < this song this song this song <EOS>
#
# 2m 27s (- 31m 1s) (5500 7%) 4.4564
# > song relevant
# = this song is so relevant in america its not even funny anymore
# < this is america this is america <EOS>
#
# > coryxkenshin could
# = coryxkenshin could have easily done those moves
# < this is america this is america <EOS>
#
# 2m 41s (- 30m 55s) (6000 8%) 4.7916
# > one ever
# = no one ever made a song like this one and no one willl
# < this is america . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > america whole
# = and now it's not just america , it's the whole world . . .
# < this is america . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 2m 54s (- 30m 43s) (6500 8%) 4.7394
# > swear crystal
# = swear he had a crystal ball . police shootings have been happening but u see protests , fires , and even kids with facemasks like its just too accurate loudly_crying_face
# < i can't here after the people <EOS>
#
# > kids white
# = its the kids with the white mask on . its scary . .
# < i can't here after the song <EOS>
#
# 3m 7s (- 30m 23s) (7000 9%) 4.4651
# > song ahead
# = this song was ahead of its time
# < this is america the <EOS>
#
# > annoying song
# = the most annoying song in history
# < this is america the <EOS>
#
# 3m 19s (- 29m 59s) (7500 10%) 4.2958
# > go go
# = go ! go ! go ! go ! go !       who's next ?       1 35
# < this is america is a song <EOS>
#
# > people think
# = people think america is a rich country a great one but this song shows what it really is america uses music to cover it all movies too
# < this is america is a <EOS>
#
# 3m 33s (- 29m 44s) (8000 10%) 4.4429
# > song becoming
# = this song is becoming more and more accurate . . . . . .
# < this is america is
#
# > poor guy
# = that poor guy
# < this is america is  <EOS>
#
# 3m 46s (- 29m 33s) (8500 11%) 4.5195
# > else expect
# = who else did not expect that this is how the song is after hearing it on tiktok
# < i is this is america , this is
#
# > whos november
# = whos here for the november 3rd election ?
# < i is this is america , this is
#
# 3m 59s (- 29m 15s) (9000 12%) 4.2749
# > looks like
# = he looks like he has backpains with the moves his hitting
# < i like the people , the people , but i like the people , but i like the people , but i like the people , but i like the people , but i like the people , the people
#
# > america stop
# = america will stop being like this once america's government is not 95% jewish anymore , there thats the solution
# < this song is america , but i like the people , but i like the people , but i like the people , but i like the future <EOS>
#
# 4m 12s (- 28m 58s) (9500 12%) 4.1776
# > donald trump
# = donald trump * pay chlidren for sexual business *                   this is america .
# < this is america is a  <EOS>
#
# > 0 39
# = 0 39 when im peeling an orange and its oil squirts in my eye
# < this is america is the <EOS>
#
# 4m 24s (- 28m 41s) (10000 13%) 4.1981
# > 0 40
# = 0 40 why is he winking ?
# < this is the <EOS>
#
# > sitting class
# = me sitting in class       silent kid goes in bag ( whispers ) " i'm sorry but this america . "       me 0 40
# < this is this <EOS>
#
# 4m 37s (- 28m 27s) (10500 14%) 4.1660
# > f ck
# = f * ck this blm terrorist movement
# < i just a people who are wearing masks <EOS>
#
# > wait america
# = wait , its all america ?
# < america is america <EOS>
#
# 4m 51s (- 28m 17s) (11000 14%) 4.4458
# > hey im
# = hey im sorry im kinda confused about him shooting a whole lot of people is supposed to mean . can someone explain it to me please ?
# < i the the this the this the this the <EOS>
#
# > love come
# = i love how we come back to this song , i still can't believe racism is happening , i mean its 2020 *
# < i the the this the this the this the <EOS>
#
# 5m 5s (- 28m 5s) (11500 15%) 4.3453
# > dear stranger
# = dear stranger , whoever reads this may your parents live over 100 years .
# < this is the <EOS>
#
# > amrica country
# = amrica is not a country
# < this is the <EOS>
#
# 5m 18s (- 27m 50s) (12000 16%) 4.2979
# > 2 37
# = 2 37 he predicts the one protester in recent videos riding a horse
# < 2 28 is this . <EOS>
#
# > song 2018
# = this song in 2018 people dancing to it             this song now a song for racism and black lives matter
# < this song is this song <EOS>
#
# 5m 32s (- 27m 40s) (12500 16%) 4.3077
# > noticed lot
# = i noticed a lot of the cars used in this are older models ? what symbolism do you think it has ? i think its a reference to the 1992 la race riots
# < this is the  the
#
# > exchange student
# = exchange student expectation america is going to be so fu-             * reality *
# < this is the  <EOS>
#
# 5m 46s (- 27m 31s) (13000 17%) 4.5105
# > fun fact
# = fun fact america is a continent , not a country .
# < this is the <EOS>
#
# > black lives
# = black lives matter raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
# < i is the <EOS>
#
# 6m 0s (- 27m 21s) (13500 18%) 4.2237
# > really predicting
# = he really over here predicting the future
# < this is the  . . . . . . . . . .
#
# > america neutral_face
# = this is america neutral_face
# < this is america * <EOS>
#
# 6m 12s (- 27m 4s) (14000 18%) 4.1581
# > everyone song
# = why is everyone in the song black ? this is america , not africa . .
# < this song is a song <EOS>
#
# > song relevant
# = this song is so relevant in america its not even funny anymore
# < this song is song , now . . . . . . .
#
# 6m 26s (- 26m 52s) (14500 19%) 4.2891
# > guy explain
# = my guy explain black history in 4mins , what a god .
# < this song is a <EOS>
#
# > song getting
# = this song is getting more realistic every fucking day . . .
# < this song is song a song <EOS>
#
# 6m 39s (- 26m 39s) (15000 20%) 4.3352
# > listen differently
# = i listen to this very differently now than i did 2 years ago .
# < i is the this is <EOS>
#
# > video viral
# = why is the video just viral now ?
# < this is song the song
#
# 6m 54s (- 26m 31s) (15500 20%) 4.4534
# > put focken
# = put a focken shirt on
# < i dont see the this is the <EOS>
#
# > fact song
# = the fact this song is 2 years old and there are comments from mere hours ago shows how important and still relevant this song is .
# < i this song is song <EOS>
#
# 7m 8s (- 26m 19s) (16000 21%) 4.2692
# > lando drop
# = when did lando drop a mixtape face_with_tears_of_joy
# < i is this this <EOS>
#
# > nigeria
# = this is nigeria
# < this is is this <EOS>
#
# 7m 21s (- 26m 4s) (16500 22%) 4.1032
# > bidens america
# = this is bidens america ! blm america . be afraid
# < this is america
#
# > dislikes fascist
# = all dislikes are from fascist donald trump supporters get that bunker boy out of office
# < i people are the this  ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
#
# 7m 34s (- 25m 51s) (17000 22%) 4.1942
# > childish gambino
# = childish gambino is so fucking smart . he is a genius .
# < is a  <EOS>
#
# > 2 36
# = 2 36 the white horse riding in right after showing people wearing masks the end is near
# < 2 28 the . <EOS>
#
# 7m 48s (- 25m 40s) (17500 23%) 4.2736
# > dont like
# = i dont like when he shoots someone (
# < i like this this this the <EOS>
#
# > america ft
# = this is america ft . covid19       directed by donald trump
# < this is america america <EOS>
#
# 8m 2s (- 25m 27s) (18000 24%) 4.3543
# > sad message
# = sad that the message in this song became true
# < i the the this this is <EOS>
#
# > teacher slaves
# = teacher not all of them were slaves there was people that was black but they have money me okay
# < i just to this . . . . . . . <EOS>
#
# 8m 17s (- 25m 18s) (18500 24%) 4.3061
# > predict future
# = you can predict the future
# < the people who disliked this is  <EOS>
#
# > predicted 2020
# = they predicted 2020 ! lol
# < this is a  <EOS>
#
# 8m 30s (- 25m 4s) (19000 25%) 4.2142
# > america
# = this is america .
# < this is america america
#
# > swear like
# = i swear its like he predicted the future-
# < i like this is a <EOS>
#
# 8m 43s (- 24m 50s) (19500 26%) 4.0323
# > someone tell
# = can someone tell me what message yall get out this song i have a school assignment and ion get no message from this song plz and thank you black_heart
# < why did not only one to this song <EOS>
#
# > karens hear
# = karens when they hear somebody say another launguage
# < why is here after george floyd was going on in 2020 <EOS>
#
# 8m 57s (- 24m 37s) (20000 26%) 4.1333
# > would never
# = i would never go to america im from philippines
# < i is the , <EOS>
#
# > masterpiece heartbreaking
# = this is a masterpiece . heartbreaking that the world hasn't improved much after 2 years .
# < this is
#
# 9m 10s (- 24m 22s) (20500 27%) 3.9190
# > hate america
# = we hate america smiling_face_with_smiling_eyes
# < america is america america <EOS>
#
# > 2 29
# = 2 29 wtf they had mask on how did he know
# < 2 28 the <EOS>
#
# 9m 23s (- 24m 10s) (21000 28%) 3.9829
# > face_with_tears_of_joy
# = face_with_tears_of_joy
# < this is
#
# > he's genius
# = he's a genius !
# < this is the
#
# 9m 38s (- 23m 59s) (21500 28%) 4.0391
# > u know
# = if u only know this song from the news and tiktok then your sad
# < i cant breathe . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > 2 27
# = 2 27 just noticed the kids wearing face masks face_with_open_mouth
# < 2 2  <EOS>
#
# 9m 51s (- 23m 45s) (22000 29%) 3.9963
# > wtf killing
# = wtf you are killing people
# < the fact  <EOS>
#
# > relevant song
# = this should be the most relevant song in society right now
# < this song is song now <EOS>
#
# 10m 5s (- 23m 32s) (22500 30%) 3.9731
# > year look
# = and in this year look at the chickens meaning today about the popeye chicken sandwiches craze and on the teir with the kids recording they got face masks on like wtf @donald glover
# < the fact that this is the <EOS>
#
# > two fortnite
# = there were two fortnite dances in this video which is two too many
# < 1 55 is    <EOS>
#
# 10m 19s (- 23m 19s) (23000 30%) 3.9494
# > black lives
# = black lives matter ! ! https //teespring . com/i-can-t-breathe-3081 ? pid=823&fbclid=iwar1jrtdf2z-rmy_ed1cav8dap8u_dpup1mml1zrr1ofzcbw8npra412biee
# < black lives matter
#
# > every time
# = every time a black man is killed by the police this video pops up in my recommendations ! how fd up is that folks ? i long for the day that doesnt happen anymore .
# < this is this  <EOS>
#
# 10m 33s (- 23m 7s) (23500 31%) 3.9818
# > song protest
# = this song should be at protest to still show this is america       the reality we live still
# < this song is a song <EOS>
#
# > raised_fist raised_fist
# = raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone deciduous_tree paw_prints
# < raised_fist raised_fist
#
# 10m 46s (- 22m 54s) (24000 32%) 3.9200
# > tiktok ruined
# = who is here before tiktok ruined this song
# < 0 52 <EOS>
#
# > really predicting
# = he really over here predicting the future
# < this is is  <EOS>
#
# 11m 1s (- 22m 42s) (24500 32%) 3.9206
# > dont like
# = i dont like this song or artist yet here i am watching it again . . .
# < i like he he predicted the the <EOS>
#
# > america; call
# = this is america; so call me maybe
# < he predicted the the <EOS>
#
# 11m 14s (- 22m 28s) (25000 33%) 3.9415
# > racism getting
# = racism isn't getting worse it's getting recorded "
# < this is the <EOS>
#
# > 0 46
# = 0 46 my pisces sister coming to ruin my vibe
# < 0 40 when the people who the <EOS>
#
# 11m 28s (- 22m 15s) (25500 34%) 3.9361
# > else watching
# = who else is watching this on election night ? ?
# < who else is here the in the <EOS>
#
# > type music
# = this is the type of music video that i wont get bored of watching
# < this is this is the <EOS>
#
# 11m 42s (- 22m 4s) (26000 34%) 4.0819
# > anyone thinks
# = anyone who thinks this song is only relevant now has not been paying attention to the last couple of decades
# < police be trippin now i dont get it was like this is america . <EOS>
#
# > 0% girls
# = 0% girls       0% flex       100% straight facts
# <                            . <EOS>
#
# 11m 56s (- 21m 50s) (26500 35%) 3.9258
# > never knew
# = i never knew the meaning behind this when i was a kid , i was just boppin'
# < i i this this this this song is <EOS>
#
# > people way
# = people who is way into blm when the blm is going around i realized how racist is this song
# < i love how he was a in the . <EOS>
#
# 12m 10s (- 21m 37s) (27000 36%) 3.8818
# > two fortnite
# = there were two fortnite dances in this video which is two too many
# < 1 55
#
# > oh god
# = oh my god troy did end up travelling all around the world , doing all kinds of things after all
# < i be is
#
# 12m 23s (- 21m 24s) (27500 36%) 3.7792
# > kid 2nd
# = the kid on that 2nd floor wearing the mask too flushed_face face_with_medical_mask
# < the dislikes are from the <EOS>
#
# > shit 680
# = how can this shit has 680 million views and 9 . 7 million upvotes ? ? such a waste video .
# < this is the future <EOS>
#
# 12m 37s (- 21m 10s) (28000 37%) 3.8832
# > pretty late
# = it's pretty late to comment but have you seen south africa like they complaining about their land but it really is much worse here in south africa weary_face
# < it's been going on the police and the police <EOS>
#
# > america
# = that is not america
# < this is america
#
# 12m 50s (- 20m 57s) (28500 38%) 3.8521
# > offense american
# = no offense to all the american but i used to want to live there but its to unsafe and shit for me to survive
# < i am of the  . <EOS>
#
# > describes america
# = this describes what america is up to right now
# < this is america <EOS>
#
# 13m 5s (- 20m 45s) (29000 38%) 3.8496
# > american clearly
# = i am not an american but i can clearly see the message
# < i is this this this this is  <EOS>
#
# > want black
# = we just want to be black in peace . why is that a crime ? loudly_crying_face
# < i am the
#
# 13m 19s (- 20m 33s) (29500 39%) 3.9525
# > sang two
# = i sang two years ago and your song was hit now we know that black people in america are oppressed , so we are in iraq regional_indicator_symbol_letter_i regional_indicator_symbol_letter_q regional_indicator_symbol_letter_i regional_indicator_symbol_letter_q with you and love you we support you
# < 0 52 when you just a
#
# > imagine going
# = imagine going through your 5 year old cousins history and seeing this .
# < the the the
#
# 13m 34s (- 20m 21s) (30000 40%) 3.8353
# > love leave
# = love it or leave it . i hear north korea is nice this time of year .
# < i love how this is the <EOS>
#
# > agree song
# = we all have to agree that this song is incredible .
# < this song this song song <EOS>
#
# 13m 47s (- 20m 7s) (30500 40%) 3.8411
# > ahead time
# = this was so ahead of time             rip all my brothers and sisters who died because of our colour dove red_heart
# < this is a . <EOS>
#
# > anyone explain
# = can anyone explain the message here plz       i'm not from america
# < anyone else explain why he predicted the <EOS>
#
# 14m 2s (- 19m 55s) (31000 41%) 3.8482
# > people disliked
# = the people that disliked are racist
# < people who came to the people who came to the song in the <EOS>
#
# > wonder many
# = i wonder how many murders this song is directly attributable to .
# < i just came to the this the <EOS>
#
# 14m 16s (- 19m 42s) (31500 42%) 3.9035
# > wearing masks
# = they wearing masks at 2 27 ? this was 2 years ago , im shook .
# < the the are from the <EOS>
#
# > song never
# = this song will never stop being relevant .
# < this song is more relevant in 2020 . <EOS>
#
# 14m 30s (- 19m 29s) (32000 42%) 3.7502
# > say fuck
# = say it with me fuck the police .
# < why are you      <EOS>
#
# > riot background
# = all the riot in the background and burning police cars . damn this video is gonna get loads of traction every time we have another george floyd , trayvon martin etc etc
# < all the people who disliked ? ? <EOS>
#
# 14m 44s (- 19m 16s) (32500 43%) 3.7753
# > bosniaaaa eat
# = this is bosniaaaa we eat burek
# < i just realized this is
#
# > raised_fist dark_skin_tone
# = raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist medium_light_skin_tone raised_fist
# < raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone  <EOS>
#
# 14m 58s (- 19m 3s) (33000 44%) 3.8504
# > people tiktok
# = all the people on tiktok using this but remixed .
# < people who is this   . <EOS>
#
# > else death
# = who else here after the death of george floyd ?
# < who else else after this song this song song was 2 years <EOS>
#
# 15m 13s (- 18m 52s) (33500 44%) 4.0325
# > covid19 5g
# = covid19 and 5g are related , see banned doctors on infowars . com and mark passio natural laws
# < the police be a     <EOS>
#
# > trying understand
# = trying to understand what does all this mans @_@
# < the fact that is a  <EOS>
#
# 15m 28s (- 18m 39s) (34000 45%) 3.8613
# > one gets
# = am i the only one who gets like lowkey scared watching this because of how true it is ? ?
# < i am the one the this the  . <EOS>
#
# > thailand discriminate
# = thailand does not discriminate against blacks . raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone regional_indicator_symbol_letter_t regional_indicator_symbol_letter_h
# < my teacher not the this this  <EOS>
#
# 15m 42s (- 18m 25s) (34500 46%) 3.6421
# > wtf trash
# = wtf trash
# < this is is a . <EOS>
#
# > gay something
# = is he gay or something
# < he is a . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 15m 55s (- 18m 12s) (35000 46%) 3.7132
# > aging like
# = this is aging like fine wine
# < this is america is the
#
# > literally crying
# = i am literally crying .
# < i just noticed the this <EOS>
#
# 16m 10s (- 17m 59s) (35500 47%) 3.7802
# > looks like
# = looks like childish gambino wasn't just commentating , he was prophesizing .
# < he looks like he shot the guy <EOS>
#
# > 2 years
# = 2 years later , if you'ar watching this you'ar a legend
# < 2 years later and still still america <EOS>
#
# 16m 23s (- 17m 45s) (36000 48%) 3.7250
# > goodbye dear
# = goodbye my dear trump raising_hands waving_hand waving_hand
# < he he predicted the the <EOS>
#
# > america catch
# = this is america , don't catch you slipping ya "
# < this is america . . . .
#
# 16m 38s (- 17m 33s) (36500 48%) 3.7289
# > okay americans
# = okay . americans , so this is america ?
# < hello , all the people who disliked this <EOS>
#
# > video seems
# = this video seems like a subliminal foreshadowing for 2020 . example the kids in 2 28 with masks on
# < this video video video the video . <EOS>
#
# 16m 52s (- 17m 19s) (37000 49%) 3.6526
# > ignorant take
# = the ignorant will take offense , the wise will take a lesson . .
# < the a the this <EOS>
#
# > one
# = no one             childish gambinos spine right_arrow_selector up-right_arrow_selector down_arrow_selector up_arrow_selector left_arrow_selector down-left_arrow_selector up-left_arrow_selector right_arrow_curving_up_selector right_arrow_curving_left_selector right_arrow_curving_down_selector counterclockwise_arrows_button
# < no one
#
# 17m 6s (- 17m 6s) (37500 50%) 3.7144
# > whole video
# = this whole video is just gay choreography with background music
# < this video is a video . .
#
# > i'm brazilian
# = i'm brazilian and i perfectly understand what's happening to america . and i feel bad for you ! raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone #blacklivesmatter
# < i'm , i to be a
#
# 17m 20s (- 16m 52s) (38000 50%) 3.7790
# > killing black
# = but why is it killing the black people he's not making no sense
# < black and black people who is <EOS>
#
# > supposed funny
# = is this supposed to be funny
# < this is the the the .  <EOS>
#
# 17m 35s (- 16m 40s) (38500 51%) 3.7242
# > good song
# = good song but did he have to kill the choir
# < this is the song the the . <EOS>
#
# > put shirt
# = put a shirt on ! squinting_face_with_tongue
# < is a   <EOS>
#
# 17m 49s (- 16m 27s) (39000 52%) 3.7824
# > america like
# = what america is like
# < this is america like the is america <EOS>
#
# > song didnt
# = this song didnt age well ( aside from this , acab , black lives matter ! i support all of you . i grieve with you ! )
# < this song is a the song is <EOS>
#
# 18m 4s (- 16m 14s) (39500 52%) 3.6608
# > else minneapolis
# = who else is here after minneapolis police applied pressure on a george floyds neck until he died " nope im here since this song come out in 2018
# < who else is here after george floyd ? <EOS>
#
# > stupid ass
# = stupid ass song
# < this is the to the is
#
# 18m 18s (- 16m 1s) (40000 53%) 3.5453
# > dumb george
# = its so dumb how after george floyd died they say this song now makes sense and act as racism just started and most of them dont even care they do it just for fame
# < i just here after george floyd was a george floyd and the police . <EOS>
#
# > tik tok
# = tik tok ?
# < who is here after the <EOS>
#
# 18m 33s (- 15m 48s) (40500 54%) 3.7469
# > thumbs_up light_skin_tone
# = thumbs_up light_skin_tone thumbs_up medium_light_skin_tone thumbs_up medium_skin_tone thumbs_up medium_dark_skin_tone thumbs_up dark_skin_tone thumbs_up medium_dark_skin_tone thumbs_up medium_skin_tone thumbs_up medium_light_skin_tone thumbs_up light_skin_tone thumbs_up medium_light_skin_tone thumbs_up medium_skin_tone thumbs_up medium_dark_skin_tone thumbs_up dark_skin_tone
# < thumbs_up light_skin_tone thumbs_up medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone
#
# > never thought
# = never thought that all the things in this video will actually come true but here we are in 2020 and we can witness this live on cnn
# < i i i i . i . . <EOS>
#
# 18m 47s (- 15m 34s) (41000 54%) 3.5143
# > someone talks
# = someone talks in another language       karens
# < someone
#
# > sublime imagery
# = sublime imagery . outstanding video clip
# < 3 43 is a <EOS>
#
# 19m 1s (- 15m 21s) (41500 55%) 3.5104
# > whats happening
# = and this is whats happening right now blacklivesmatter ! ! ! ! !
# < this is is <EOS>
#
# > song
# = this is a song ?       what a shitty song
# < this song is song <EOS>
#
# 19m 15s (- 15m 8s) (42000 56%) 3.6507
# > look like
# = he look like hes on crack
# < he looks like like like like like like <EOS>
#
# > song's still
# = song's still trash
# < i still still this this this is <EOS>
#
# 19m 30s (- 14m 54s) (42500 56%) 3.5760
# > tiktok mix
# = the tiktok mix post malone of this song is a disappointment
# < the this this the to  <EOS>
#
# > 2018 worst
# = 2018 i was the worst year ever !       2020 yeah . . . sure
# < this is a  . <EOS>
#
# 19m 44s (- 14m 41s) (43000 57%) 3.5369
# > 2020_ fire
# = 2020_ fire oncoming_fist
# < this is * <EOS>
#
# > america stop
# = america will stop being like this once america's government is not 95% jewish anymore , there thats the solution
# < this is america america . .  .   <EOS>
#
# 19m 58s (- 14m 28s) (43500 57%) 3.4370
# > 0 52
# = 0 52 when the real song starts
# < 0 52 when you see the song is the <EOS>
#
# > great song
# = such a great song ! someone said that what happens in america happens in india after 10 years . shushing_face
# < this this song song song song the song the <EOS>
#
# 20m 13s (- 14m 14s) (44000 58%) 3.4954
# > exactly america
# = this is exactly how america is right now . rip george floyd .
# < this is america .
#
# > song still
# = this song ( still ) gives me nightmares . the sad fact is that it is a spot-on representation of republican america = guns and violence and war .
# < this song is still relevant <EOS>
#
# 20m 28s (- 14m 1s) (44500 59%) 3.7185
# > ahbed troy
# = where is ahbed troy ? !
# < i just don't understand understand what a song <EOS>
#
# > genius song
# = the genius of this song and video still stuns me 2 years later .
# < the most song song song <EOS>
#
# 20m 42s (- 13m 48s) (45000 60%) 3.5744
# > goodbye dear
# = goodbye my dear trump raising_hands waving_hand waving_hand
# < oh if you you shoot the man , . . . . <EOS>
#
# > donald glover
# = why does donald glover look so much like childish gambino face_with_tears_of_joy thinking_face
# < donald glover predicted the future . <EOS>
#
# 20m 56s (- 13m 34s) (45500 60%) 3.5752
# > wanted ask
# = i wanted to ask why there is so much negativity and there is not one white person we are all human can this be considered racism ?
# < i i to this a this a and i this <EOS>
#
# > dancing ass
# = he dancing his ass off ! this is still america two years later .
# < this the are are in the ? <EOS>
#
# 21m 11s (- 13m 21s) (46000 61%) 3.5658
# > kenosha winsconsin
# = kenosha winsconsin shooting brought me here . . . . . .       again - . -
# < hey , im scared me this song is about racism <EOS>
#
# > would shoot
# = why would you shoot your own kind . .
# < why did you shoot him <EOS>
#
# 21m 24s (- 13m 7s) (46500 62%) 3.5252
# > fuckin world
# = this is the fuckin * world
# < the world world country is not a continent <EOS>
#
# > dont like
# = if you dont like life in america . . . . dont life in america dude
# < dont dont get a song <EOS>
#
# 21m 39s (- 12m 53s) (47000 62%) 3.5918
# > racism stopped
# = racism has to stopped
# < racism is the the  .
#
# > bumping 4th
# = bumping this on the 4th of july bc i fucking hate the united states
# < this is the the a <EOS>
#
# 21m 52s (- 12m 39s) (47500 63%) 3.4249
# > american white
# = american is white not black !
# < white the white . white the . the . <EOS>
#
# > thought girl
# = i thought he was a girl in the beggining lmao
# < i came here after the george floyd was a  <EOS>
#
# 22m 6s (- 12m 26s) (48000 64%) 3.6340
# > someone dropped
# = someone dropped vodka       russians * pulls gun out and shots him *       this is russia
# < someone someone * * * * * * * * * * * * * * * * * * <EOS>
#
# > black lives
# = black lives matter ! ! https //teespring . com/i-can-t-breathe-3081 ? pid=823&fbclid=iwar1jrtdf2z-rmy_ed1cav8dap8u_dpup1mml1zrr1ofzcbw8npra412biee
# < black lives matter raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist <EOS>
#
# 22m 20s (- 12m 12s) (48500 64%) 3.5504
# > song gotten
# = this song have gotten me chills ever since i've heard it , it goes both ways from native americans to african americans , and also in canada as well
# < this song is a a of <EOS>
#
# > 2 years
# = 2 years ago . still relevant . americans forgot their damn amendments .
# < 2 years later . <EOS>
#
# 22m 34s (- 11m 58s) (49000 65%) 3.3337
# > could make
# = could make an emote for fortnite ! 0 55
# < i just to to the this song this song  <EOS>
#
# > someone speaks
# = someone speaks a different language karen 0 52
# < someone * * * * * *
#
# 22m 48s (- 11m 44s) (49500 66%) 3.4340
# > 2 26
# = 2 26 wtf . . . this depicts whats happening rn . riots . police . covid . this is america grimacing_face face_screaming_in_fear face_with_hand_over_mouth
# < 2 2 29 now . . . <EOS>
#
# > reason came
# = the reason why i came here is because of racism and the deaf of george floyd .
# < the the the the the the the the the <EOS>
#
# 23m 1s (- 11m 30s) (50000 66%) 3.2808
# > love song
# = i love how this song is so relevant right now .
# < i love love this song is the <EOS>
#
# > someone speaks
# = someone speaks a different language karen 0 52
# < someone * a
#
# 23m 15s (- 11m 17s) (50500 67%) 3.3355
# > 2 23
# = 2 23 these damn ninjas doin fortnite dances       look whut this trash game done to this poor generation
# < 2 years later and this song is <EOS>
#
# > last weeks
# = these last few weeks i am seeing that there are many attacks on black people by the police and white people . why ?
# < the fact the people the this . <EOS>
#
# 23m 30s (- 11m 3s) (51000 68%) 3.4253
# > 0% girls
# = 0% girls       0% flex       100% straight facts
# < childish gambino is so many times
#
# > amrica continente
# = amrica is a continente , burros
# < this is is <EOS>
#
# 23m 45s (- 10m 50s) (51500 68%) 3.5556
# > trash music
# = this is trash " music "
# < this is music video is <EOS>
#
# > portrait society
# = a portrait of our society . not just a song or a video , but a piece of contemporary art . i get chills every single time .       raised_fist
# < we are all the and this . <EOS>
#
# 23m 59s (- 10m 36s) (52000 69%) 3.4338
# > guess black
# = i guess this is for the black people's becuse they didn't get a humans rights because the government is increasingly cruel
# < i can't breath
#
# > song makes
# = this song just makes me wish i lived in canada
# < this song is more and now . . . <EOS>
#
# 24m 13s (- 10m 23s) (52500 70%) 3.4762
# > frick u
# = why the frick did u kill the man-
# < why u did u the the 2 years ago <EOS>
#
# > ffff watch
# = what the ffff did i just watch
# < this is what is . . . . .
#
# 24m 28s (- 10m 9s) (53000 70%) 3.3676
# > black lives
# = black lives mettar oncoming_fist dark_skin_tone oncoming_fist medium_dark_skin_tone oncoming_fist medium_skin_tone oncoming_fist medium_light_skin_tone oncoming_fist light_skin_tone
# < black lives matter
#
# > lets take
# = lets all take a moment to imagine if this song came out now in 2020 .
# < lets be honest to a song
#
# 24m 41s (- 9m 55s) (53500 71%) 3.3065
# > warned us
# = he warned us it was going to get worst
# < he was us the us , the guy was a real of the guy <EOS>
#
# > song made
# = this song was made to promote the good things in america not about racism
# < this song was made 2 years ago and still . <EOS>
#
# 24m 54s (- 9m 41s) (54000 72%) 3.3621
# > non american
# = as a non american , can somebody explain this to me why this is so relevant ?
# < american american american american
#
# > black people
# = black people they are human beings there are men who are beautiful , very smart , and pretty black girls , racism is the stupidest thing in life .
# < the people are here for the people who the
#
# 25m 7s (- 9m 27s) (54500 72%) 3.2182
# > whats covid
# = whats with the covid masks @2 29 ?
# < he are the the the <EOS>
#
# > i'm going
# = i'm going to tell my children that this is justin beiber
# < i'm going to be a song . <EOS>
#
# 25m 22s (- 9m 13s) (55000 73%) 3.3068
# > youll like
# = youll like this https //youtu . be/a0adpbdq6lk
# < like like like like <EOS>
#
# > song fucking
# = this song fucking sucks
# < this song is relevant now . <EOS>
#
# 25m 35s (- 8m 59s) (55500 74%) 3.4291
# > songs almost
# = the songs almost like they knew what was gonna happen in america
# < this songs like the people to this song <EOS>
#
# > someone played
# = someone played this at a protest
# < someone should play this song
#
# 25m 49s (- 8m 45s) (56000 74%) 3.4474
# > reason love
# = only reason i love this song is because of how calm he is after murdering a full church choir
# < i love the the the is <EOS>
#
# > jesus afraid
# = jesus i very . . . afraid about the humanity
# < i wish i want to be in the
#
# 26m 3s (- 8m 31s) (56500 75%) 3.2720
# > hate song
# = i hate the song
# < i hate this song is now <EOS>
#
# > well guys
# = well guys , shits gonna go down tomorrow . lets hope for the best .
# < well i don't know im so . . . <EOS>
#
# 26m 17s (- 8m 18s) (57000 76%) 3.2551
# > need ''this
# = we need a ''this is america 2'' or something
# < we we need to stop this this is america . . . . . .
#
# > police triping
# = police be triping now "             this is america
# < police be trippin' " " " <EOS>
#
# 26m 30s (- 8m 4s) (57500 76%) 3.2506
# > 0 52
# = 0 52 how u shoot in roblox arsenal       1 51 how he streches
# < 0 52 when people
#
# > new national
# = the new national anthem
# < this is the a is <EOS>
#
# 26m 43s (- 7m 49s) (58000 77%) 3.2703
# > song kinda
# = this song kinda predicted 2020
# < this song is a to of the <EOS>
#
# > millions views
# = why does this have millions of views ?
# < why is this views this song is a song <EOS>
#
# 26m 55s (- 7m 35s) (58500 78%) 3.1487
# > man must
# = man he must be doing a lot of covax to get that aim or he on controller
# < man man man predicted the future . <EOS>
#
# > happy halloween
# = happy halloween !
# < so stop . . . . . . . . . . . . . . . . . . . . . .
#
# 27m 10s (- 7m 22s) (59000 78%) 3.3787
# > come watched
# = i come here after i watched this version without music ! woozy_face
# < i come here after i . <EOS>
#
# > america mutha-fuccas
# = america . . . you mutha-fuccas owe me ! #reparations
# < america is . . . . . . <EOS>
#
# 27m 23s (- 7m 8s) (59500 79%) 3.2994
# > looking song
# = looking at this song now . nothing changed and it sucks to see no matter how many riots we do . police continue to harm and dont do a political change
# < i just song this song the <EOS>
#
# > sheer amount
# = the sheer amount of metaphors , analogies and other societal commentaries are astounding . and entirely relevant .
# < the amount of the comments ,
#
# 27m 37s (- 6m 54s) (60000 80%) 3.2315
# > todays elections
# = todays the elections . im scared .
# < the . . . . . <EOS>
#
# > dont live
# = i dont live in america but i stand against racism #blacklivesmatter
# < i dont live in america but the video is , <EOS>
#
# 27m 51s (- 6m 40s) (60500 80%) 3.2057
# > nice make
# = its not nice to make fun of asbergers
# < not nice to make a song , but the message is a lot of the world and i will never get a message of the world . <EOS>
#
# > mess
# = this is mess up
# < this is the the <EOS>
#
# 28m 5s (- 6m 26s) (61000 81%) 3.2380
# > song end
# = this song is the end credits of america
# < this song is different in in the <EOS>
#
# > america 2020
# = this is america now 2020 . slightly_frowning_face
# < this is america america <EOS>
#
# 28m 19s (- 6m 12s) (61500 82%) 3.2267
# > age well
# = this did not age well .
# < this is how well . . . . . . . . . .  . . . . . . . . . . . . . . .  . . . . . . . . .
#
# > scary everything
# = its scary because everything gambino talks about in the song is true
# < its aged so sad , but this song is more relevant . <EOS>
#
# 28m 33s (- 5m 59s) (62000 82%) 3.2103
# > song makes
# = this song just makes me wish i lived in canada
# < this song makes me chills it is still relevant as as well <EOS>
#
# > else remembers
# = who else remembers this guy from that show " community " ?
# < who else is here after the the . this <EOS>
#
# 28m 46s (- 5m 45s) (62500 83%) 3.3255
# > im litterally
# = im litterally comeback here just to check the comment about the american chaos right now d
# < im im the here because of the people this song <EOS>
#
# > pause 2
# = pause at 2 29 they predicting this man made disease
# < 2 2 . . . . . . . . . <EOS>
#
# 29m 1s (- 5m 31s) (63000 84%) 3.2977
# > soo insane
# = its soo insane that they named * 2 continents * " america " because of this song
# < why does not have you kill the <EOS>
#
# > think song
# = i think this song is more american than american national anthem .
# < i think this song is more than american <EOS>
#
# 29m 15s (- 5m 17s) (63500 84%) 3.1692
# > four years
# = four more years of trump and you can call this song " this was america "
# < now is more than people in 2020 <EOS>
#
# > else minneapolis
# = who else is here after minneapolis police applied pressure on a george floyds neck until he died " nope im here since this song come out in 2018
# < who else is here after george floyd
#
# 29m 29s (- 5m 4s) (64000 85%) 3.2832
# > i'm pretty
# = i'm pretty sure race relations in this country is worse or close to worse than it was in the 1950s .
# < i'm i'm a this , this i'm a but this . <EOS>
#
# > karens someone
# = karens when someone is not speaking english in chinese restaurant
# < someone should go
#
# 29m 43s (- 4m 50s) (64500 86%) 3.2699
# > video clip
# = this video clip turn to the reality *
# < this video video has so many views . <EOS>
#
# > claim 1
# = claim your here before 1 billion views ticket       backhand_index_pointing_down
# < 1 55
#
# 29m 57s (- 4m 36s) (65000 86%) 3.1668
# > came back
# = i came back to this song to see if i can understand why another innocent black man was killed . of course the answer i got was this is america .
# < i came back here after george floyd was murdered by the police brutality , this is america <EOS>
#
# > part says
# = the part where he says i'm a celly freaks me out . that's how we all look like today . masks on our face and cells in our hand .
# < the part where he predicted the future . <EOS>
#
# 30m 12s (- 4m 22s) (65500 87%) 3.1738
# > 3 43
# = 3 43 you are now in the storm run !
# < 3 in in peace and in my favorite and i don't know that was made to live in america . . . . . . . . . . . . . . .
#
# > happy american
# = am happy am not american *       - unknown
# < american american american american american * american *
#
# 30m 26s (- 4m 9s) (66000 88%) 3.2386
# > dog shit
# = dog shit song . wildly overrated artist .
# < shit shit song <EOS>
#
# > dude predicted
# = this dude predicted most of 2020
# < he predicted this predicted the future <EOS>
#
# 30m 40s (- 3m 55s) (66500 88%) 3.2465
# > 699k dislikes
# = the 699k dislikes are the people who dont support black lives matter
# < the dislikes are from from the the the the  <EOS>
#
# > god gives
# = god gives all girls boobs       me can i have some ?       god no but he can
# < my god bless america <EOS>
#
# 30m 54s (- 3m 41s) (67000 89%) 3.1428
# > almost prophetic
# = this is almost prophetic in nature . especially the pale horse rider . the pandemic in the midst of riots ?
# < this songs makes me to be the same .
#
# > still understand
# = i still didn't understand what's the message ! .
# < i still not understand understand the song , this song is america <EOS>
#
# 31m 8s (- 3m 27s) (67500 90%) 3.2384
# > sad kids
# = so sad how kids have to grow up in this kind of world . . . it devastates me . stay safe yall ! ! ! folded_hands light_skin_tone red_heart_selector
# < its sad how this the message this this song is the  <EOS>
#
# > america fuking
# = america is fuking racist nation
# < this is america ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
#
# 31m 22s (- 3m 13s) (68000 90%) 3.2823
# > song never
# = this y this song will never get old cuz it keeps happening again and again       a few days ago i guy got shot 7 times on his back infront of his own kids
# < this song has never never never never heard . <EOS>
#
# > soooooo gonna
# = soooooo are we gonna ignore the fact that this song actually came out 2017 and not 2018 ? ? ? . . . . these glitches are getting worse this year
# < we are to are the this song is <EOS>
#
# 31m 36s (- 2m 59s) (68500 91%) 3.1002
# > gwara gwara
# = gwara gwara . . . ( african's know smirking_face face_with_tears_of_joy sparkles )
# < so so many . . . . . . <EOS>
#
# > come song
# = how come this song came out 2 years ago and it predicted the future for 2020 ? ? ?
# < who come is song <EOS>
#
# 31m 49s (- 2m 46s) (69000 92%) 3.1890
# > well guys
# = well guys , shits gonna go down tomorrow . lets hope for the best .
# < well guys . . . . . . . . . . <EOS>
#
# > sociology professor
# = my sociology professor introduced me to this song having me analyze it looking behind it's deeper meaning . i love this song so much
# < all my fellow humans . . .
#
# 32m 3s (- 2m 32s) (69500 92%) 3.1837
# > assumed troy
# = so i assumed troy and abed in the morning didnt success . . .
# < troy barnes is the .
#
# > come trump
# = who come after trump win
# < who come after trump <EOS>
#
# 32m 18s (- 2m 18s) (70000 93%) 3.1999
# > music video
# = this isn't a music video , it's a documentary
# < this this video is a masterpiece <EOS>
#
# > america es
# = america es un continente eye mouth eye ok_hand
# < america is a masterpiece , you ,
#
# 32m 32s (- 2m 4s) (70500 94%) 3.1661
# > video two
# = is it me . . or this video was two years ago . and he hasnt posted in over those years . . ? and idek if people heard from him
# < this is africa . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > cringe sound
# = cringe sound and video . . . . . bleh and this views . stupid world with retarded peoples
# < what the is . . . <EOS>
#
# 32m 46s (- 1m 50s) (71000 94%) 3.1144
# > rest paradise
# = rest in paradise george floyd . you will not be forgotten .       this is amerikkka .
# < rest in peace george floyd was and the . . . . . . . . . . . . . . . . . . . .
#
# > would u
# = why would u kill someone for a video
# < why u realize the the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 33m 0s (- 1m 36s) (71500 95%) 3.1768
# > stop saying
# = stop saying that he predicted this . this is american history since the slaves ( even before then , thank you na ) . lets donate .
# < saying , this is saying " " <EOS>
#
# > america black
# = this is america black lives matter
# < this is america america . . . . <EOS>
#
# 33m 14s (- 1m 23s) (72000 96%) 3.2237
# > canada
# = this is canada
# < this is not <EOS>
#
# > ppl disliked
# = the ppl who disliked are just mad cuz it's true . . .
# < who disliked are from the who disliked
#
# 33m 28s (- 1m 9s) (72500 96%) 3.0503
# > love hes
# = i love how hes being honest , other people say america is lovely and a wonderful place , and this is what america actually is .
# < love how the only song is the only black . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > people got
# = now people got the message of this song . why it took an incident to get the message ?
# < people who got this people who are song this <EOS>
#
# 33m 42s (- 0m 55s) (73000 97%) 3.0810
# > dance moves
# = those dance moves are so cringe
# < the title * this is
#
# > europeans watching
# = europeans watching usa geting ruined popcorn popcorn haha
# < i just noticed this the song  <EOS>
#
# 33m 56s (- 0m 41s) (73500 98%) 3.0977
# > horrible disgusting
# = horrible . just disgusting what a garbage video nothing but filth
# < so just a a a . <EOS>
#
# > music video
# = this music video reflects the racism in our country       that's a good song .
# < this video is so much of whats going on a black man . <EOS>
#
# 34m 10s (- 0m 27s) (74000 98%) 3.0699
# > music seriously
# = this is music ? seriously . no rhythm or harmonies
# < this is a the of music video <EOS>
#
# > america awesome
# = america is awesome       fell proud
# < america is
#
# 34m 25s (- 0m 13s) (74500 99%) 3.2237
# > justice breanna
# = justice for breanna taylor raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
# < justice for justice for the racism ,
#
# > would gun
# = why would he gun down a bunch of teens singing a choir ?
# < why would he shot a guy in the . <EOS>
#
# 34m 39s (- 0m 0s) (75000 100%) 3.2322
# > usa america
# = this is usa no this is america
# < this is america america            <EOS>
#
# > disturbing thing
# = the disturbing thing is , he's portraying tragic events all in one while dressed as charles manson
# < the disturbing thing is , the , , this is  <EOS>

# %%
hidden_size = 256
best_encoder = EncoderRNN(input_sentence.n_words, hidden_size).to(device)
best_decoder =  AttnDecoderRNN(hidden_size, output_sentence.n_words, dropout_p=0.1).to(device)
# best_decoder =  DecoderRNN(hidden_size, output_sentence.n_words).to(device)
best_encoder.load_state_dict(torch.load(path_to_final_project + checkpoint_folder_path + encoder_checkpoint_name, map_location=torch.device('cpu')))
best_decoder.load_state_dict(torch.load(path_to_final_project + checkpoint_folder_path + decoder_checkpoint_name, map_location=torch.device('cpu')))
best_encoder.eval()
best_decoder.eval()
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(5418, 256)
#   (attn): Linear(in_features=512, out_features=40, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lstm): LSTM(256, 256)
#   (out): Linear(in_features=256, out_features=5418, bias=True)
# )

# %%
#evaluate based on training set
evaluateRandomly(best_encoder, best_decoder,pairs,n=100)
# Out:
# > nobody
# = nobody                               anonymous this is america
# < nobody
#
# > black lives
# = not only black lives matter , all lives matter
# < black lives matter raised_fist
#
# > could anyone
# = could anyone hear 21 savage ad libs
# < anyone else could anyone else to see the
#
# > got nothing
# = i got nothing to say but                   this is america
# < i got the the <EOS>
#
# > song reference
# = this song is a reference to lives around the america
# < this song is a the <EOS>
#
# > lecrae better
# = lecrae did it better .       #america
# < did he shoot the <EOS>
#
# > raised_fist medium_light_skin_tone
# = raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
# < raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
#
# > got used
# = i got to used to this is america 2 was legit singing the lyrics
# < i got to this when he shot the song <EOS>
#
# > can't breathe
# = i can't breathe " .       -george floyd , america 2020 .
# < i can't breathe <EOS>
#
# > police trippin'
# = police be trippin' now "             this did not age well
# < police be trippin now
#
# > okay americans
# = okay . americans , so this is america ?
# < americans americans in the
#
# > hey song
# = hey , , is it just me or this song is exactly what's going on in the world             damn
# < hey a song song song
#
# > going inside
# = so this is what is going on inside troys head when he is alone in the dreamatorium . .
# < this is a masterpiece .
#
# > whites always
# = whites will always be number 1
# < he will not be a america .
#
# > one hearing
# = am i the only one hearing both this is america and this is a miracle ? ive been thinking about this for 2 years . or im just looking for another piece of hidden sense and irony
# < am i the only one who the who the the <EOS>
#
# > meme song
# = this a meme song
# < this a song song <EOS>
#
# > oh god
# = oh god       this didnt age well
# < oh god what is is , <EOS>
#
# > karens speak
# = karens when you speak a different language
# < when you pause the
#
# > song wack
# = this song is wack they should make a song on this mexico
# < this song has a whole 2020 <EOS>
#
# > true hard
# = so true its hard to be black in america if your black like me you go thro a lot so all those black kids out there hold on we gona get thro it together d
# < how true it has so many dislikes ? <EOS>
#
# > haha bitch
# = haha that bitch got shot
# < that the are the <EOS>
#
# > song like
# = how can a song like this have so many dislikes ?
# < this song is like the <EOS>
#
# > literally america
# = this is literally america rn in august 2020
# < this is literally america <EOS>
#
# > hate america
# = i hate america !
# < i hate america <EOS>
#
# > song accurately
# = this song is accurately predicts what is going on right now
# < this song is the the <EOS>
#
# > guess dislikes
# = i guess the dislikes are from fbi , cia , kfc , karens , kens and trump-assers .
# < the dislikes are from the <EOS>
#
# > would create
# = would create new song " this is covid-19 "
# < he would have to be a <EOS>
#
# > guy made
# = this guy made the voice of marshal lee from adventure time
# < the guy in the
#
# > song predict
# = this song predict the future lol
# < this song song song song <EOS>
#
# > pause bit
# = pause at a bit after 3 34 . on the very right is a silhouette of someone with glasses looking at gambino .
# < at 2 29 wtf the kids wearing <EOS>
#
# > police lives
# = police lives matter ! ! blue lives matter . black lives dont matter . white lives matter !
# < police lives matter raised_fist
#
# > nice make
# = its not nice to make fun of asbergers
# < its not make a this
#
# > like prediction
# = it's like a prediction of the future . cuz america really looks like the destruction in this vid .
# < it's like like he knew what's gonna happen in america and not a continent
#
# > would never
# = i would never go to america im from philippines
# < i never thought to anyone who the song <EOS>
#
# > nigga fucking
# = that nigga is fucking ridiculous . . . . .
# < fucking fucking is a masterpiece .
#
# > really wang
# = i really wang to go to america but now not is creepy im scard im still a kid 9 years old im scard i been dreaming they kill me and imsick now
# < he really really shoot that person <EOS>
#
# > song heavily
# = this song was once heavily used as a meme . now its being used to support the #blm stuff ( i dont have anything against them )
# < this song predicted 2020 <EOS>
#
# > guy tenet
# = is this guy tenet movies actor ?
# < this guy guy guy guy from the
#
# > fun fact
# = fun fact this song was made to be a good 4th of july song . not to represent america so shut up about the riots
# < fun fact that this song is the in
#
# > america fucking
# = america is now so fucking corrupt
# < america is not a country ,
#
# > justice george
# = justice for george floyd and all other black people wrongly killed by white racist hateful cops ! we love you people so much and though we are white , we stand by you and are supporting you all !
# < justice for george floyd raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
#
# > shot choir
# = when he shot the choir and the beat dropped . i was like o did not see that coming !
# < he he shot he shot <EOS>
#
# > right ;
# = you so right ; ( . . . .
# < right now <EOS>
#
# > another rich
# = another rich dickhead telling lies about the country that's made him rich
# < imagine a person who the
#
# > imagine going
# = imagine going through your 5 year old cousins history and seeing this .
# < imagine all the dislikes are from the
#
# > else playing
# = who else playing this while trump got fired and biden is our new president ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
# < who else is watching this <EOS>
#
# > love one
# = love this one as well https //www . youtube . com/watch ? v=5mlz504jjzg , thumps up if you like it also
# < i love that one the only one who the about
#
# > joe biden
# = joe biden becomes president             usa 2021 2 00 to 2 12
# < oh biden becomes president
#
# > actually thats
# = actually thats united states of america regional_indicator_symbol_letter_u regional_indicator_symbol_letter_s . this is america globe_showing_americas
# < this is actually actually what a song <EOS>
#
# > wonder donald
# = i wonder if donald glover is a t-800 sent back in time to make this music video .
# < i wonder what does donald glover <EOS>
#
# > damn song
# = damn this song is already two years old ?
# < damn this song is the more <EOS>
#
# > music reminder
# = this music was just a reminder . . . on racism and all the shit thats going on right now !
# < this music video is a <EOS>
#
# > black peoplr
# = black peoplr matter
# < black black black and black <EOS>
#
# > who's independence
# = who's here on independence day
# < who's here after the <EOS>
#
# > looks ugly
# = he looks ugly and his movement like epilepsy
# < he looks looks like
#
# > hey i'm
# = hey i'm a irish boy from ireland and i hafe to ask why is america so fucked up
# < i'm a i'm a i'm a but the <EOS>
#
# > bruh really
# = bruh its really like what is happening right now . . its like he was showing the future sneezing_face
# < its really really really sure <EOS>
#
# > une vpn
# = when you une a vpn in europe
# < he he knew the <EOS>
#
# > still can't
# = still can't believe this is troy from community
# < i still can't believe this
#
# > keep voting
# = keep voting democrat and this song will be your anthem forever
# < my fellow my fellow is in the <EOS>
#
# > choir scene;
# = in the choir scene; the black guy on the top left hand corner is from dhar mann videos .
# < i the the the <EOS>
#
# > going stop
# = and they are not going to stop , this is america and white people
# < stop being a racist , this song <EOS>
#
# > terrible hell
# = this is a terrible what the hell is wrong with people . pouting_face
# < this is a this a
#
# > see silence
# = if you see there is a silence which is starting at 2 44 and goes on for 17 seconds this is a respect for the 17 kids who were die in florida
# < how come come from america <EOS>
#
# > sad song
# = its sad how this song is still related to america still
# < its sad how this song song song song song song song song song <EOS>
#
# > sitting class
# = me sitting in class       silent kid goes in bag ( whispers ) " i'm sorry but this america . "       me 0 40
# < me in
#
# > wake theres
# = wake up theres more than this eye
# < its just noticed that this the
#
# > like knew
# = like he knew what was going to happen in 2020
# < he knew like like like like <EOS>
#
# > tf make
# = how tf did he make a hit with a bassline like this ?
# < how tf did he actually shoot the guy ? <EOS>
#
# > holup u
# = holup u killed the real people ? ? ? ? ? ?
# < the u the the the
#
# > wtf watch
# = wtf did i just watch
# < wtf did he just watch <EOS>
#
# > anyone thinks
# = anyone who thinks this song is only relevant now has not been paying attention to the last couple of decades
# < anyone who thinks this song black lives matter <EOS>
#
# > meu deus
# = meu deus mano , a cada dia que se passa essa musica se torna mais cotidiana . ja tem o material suficiente pra um this is america part 2
# < hello in the the the the
#
# > fact theres
# = the fact that theres only black people in the clip , makes me wonder if its america or africa
# < the fact that the dislikes are from the
#
# > merica
# = what is a merica             edit thx for the like
# < this is
#
# > triste enquanto
# = triste , enquanto america for america veremos mortes como a xo george floyd loudly_crying_face loudly_crying_face loudly_crying_face loudly_crying_face loudly_crying_face loudly_crying_face
# < plot twist america is .
#
# > love america
# = if you love america so go ahead and buy this sweater       https //www . sunfrog . com/p/black-sweat-shirt-i-am-proud-i-am-american-1436760951 . html ? 184949
# < i love america <EOS>
#
# > funny americans
# = funny how all the americans are googling what this means *
# < americans americans are from this
#
# > whats covid
# = whats with the covid masks @2 29 ?
# < he kills a black people
#
# > 2 28
# = 2 28 they knew about the virus grinning_squinting_face
# < 2 28 look they wearing masks ? ? ? ? ? ? ? ? ? ? <EOS>
#
# > raised_fist light_skin_tone
# = raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone globe_showing_americas globe_showing_europe-africa globe_showing_asia-australia red_heart_selector
# < raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
#
# > video viral
# = why is the video just viral now ?
# < this video is is video .
#
# > maybe get
# = maybe i don't get it but to me the song is nothing without the video
# < i wonder get get the the <EOS>
#
# > 21 savage
# = 21 savage in the background lmao .
# < who else is here after george floyd
#
# > guess people
# = i guess all the people that disliked this don't like america , because that is what this video is . this video is america .
# < i have the people people the people the
#
# > america movie
# = if america was a movie , this was the trailer .
# < america is a continent <EOS>
#
# > george floyd
# = george floyd should have not getting so much saint and being lot of respect .       in fact , you didn't even know his backstory and the background
# < george floyd was a george floyd was a <EOS>
#
# > anyone notice
# = does anyone notice at the people on top are wearing corona virus masks ?
# < did anyone notice the kids wearing masks ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? <EOS>
#
# > non american
# = non american . i finally understand this song
# < american american american american american american * * * * this is america <EOS>
#
# > who's independence
# = who's here on independence day
# < who's here after the <EOS>
#
# > song beautiful
# = this song is so beautiful , and it's so beautifully laid out to show the problems of modern day society .
# < this song is so more relevant <EOS>
#
# > fun fact
# = fun fact this song is based off the horror movie known as * america *
# < fun fact that this song is the in
#
# > dislikes white
# = the dislikes are just white cops mad asl
# < the dislikes are from white white police <EOS>
#
# > people disliked
# = people who disliked this didn't understand the meaning of the song or they just racist
# < people who disliked this video the <EOS>
#
# > swear want
# = i swear i want someone to blast this music when they protesting
# < i swear i want to live in america and i don't even live in the back <EOS>
#
# > unironically reminds
# = unironically reminds me of how george floyd was intentionally killed . *
# < imagine this in the   <EOS>
#
# > petition everyone
# = petition for everyone to play this song when 2020 is finally over *
# < everyone gangsta till the the
#
# > america
# = this is america .       hmm yes . the floor here is made out of floor .
# < this is america
#
# > song didnt
# = this song didnt age well ( aside from this , acab , black lives matter ! i support all of you . i grieve with you ! )
# < this song is the <EOS>
#
# > fornite moves
# = what with the fornite moves . . sad when u can't dance grinning_squinting_face grinning_squinting_face grinning_squinting_face
# < what the the is

# %%
#evaluate based on test set
evaluateRandomly(best_encoder, best_decoder,test_pairs,n=100)
# print(test_pairs)
# Out:
# > anyone notice
# = no reply
# < did anyone notice the kids wearing masks ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? <EOS>
#
# > hey troy
# = no reply
# < hey .
#
# > lol didnt
# = no reply
# < i didnt really get the song song <EOS>
#
# > got plug
# = no reply
# < i got the the <EOS>
#
# > lol didnt
# = no reply
# < i didnt really get the song song <EOS>
#
# > america fucked
# = no reply
# < this is america now <EOS>
#
# > going talk
# = no reply
# < so we are to to to when he shot a song <EOS>
#
# > glad young
# = no reply
# < my my fellow is <EOS>
#
# > really know
# = no reply
# < i really really like this song <EOS>
#
# > predicted 2020
# = no reply
# < he predicted 2020 <EOS>
#
# > dislikes police
# = no reply
# < the dislikes are from from the
#
# > else watched
# = no reply
# < who else is watching this in 2020
#
# > comment know
# = no reply
# < i know the the this song
#
# > america
# = no reply
# < this is america
#
# > party free
# = no reply
# < amrica is a continent
#
# > kind pumped
# = no reply
# < what is the the .
#
# > people dont
# = no reply
# < people dont understand understand why this song
#
# > hey guy
# = no reply
# < so this guy in
#
# > guys wearing
# = no reply
# < he should have a shirt on <EOS>
#
# > song sad
# = no reply
# < this song song song song song song song song song <EOS>
#
# > wow 2
# = no reply
# < wow 2 2 2 27 the kids wearing <EOS>
#
# > hearing rappers
# = no reply
# < just a piece of the
#
# > really childish
# = no reply
# < this really really really shoot <EOS>
#
# > even though
# = no reply
# < even though i just noticed this song <EOS>
#
# > reminds days
# = no reply
# < the a piece of the
#
# > anyone else
# = no reply
# < anyone else notice the kids wearing masks ? ? ? ? ? ? ? ? ? ? ? ? ? <EOS>
#
# > like way
# = no reply
# < i like like like this song <EOS>
#
# > meme thats
# = no reply
# < this is a continent <EOS>
#
# > nigga aaron
# = no reply
# < this is the the <EOS>
#
# > guys wearing
# = no reply
# < he should have a shirt on <EOS>
#
# > song scarily
# = no reply
# < this song song song song song song song <EOS>
#
# > dude moved
# = no reply
# < the the are the <EOS>
#
# > remembers came
# = no reply
# < came came here after george floyd and the song <EOS>
#
# > best song
# = no reply
# < what song song song song song song <EOS>
#
# > meme thats
# = no reply
# < this is a continent <EOS>
#
# > funny views
# = no reply
# < why the views in the
#
# > always relevant
# = no reply
# < this is so relevant relevant now <EOS>
#
# > long day
# = no reply
# < who's watching this in 2020 <EOS>
#
# > like way
# = no reply
# < i like like like this song <EOS>
#
# > russia
# = no reply
# < this is <EOS>
#
# > there's reason
# = no reply
# < the reason why i the only one the the who the
#
# > future
# = no reply
# < he he the future <EOS>
#
# > damn song
# = no reply
# < damn this song is the more <EOS>
#
# > america gotta
# = no reply
# < this is america .
#
# > telling kids
# = no reply
# < the kids are wearing wearing masks <EOS>
#
# > russia
# = no reply
# < this is <EOS>
#
# > damn song
# = no reply
# < damn this song is the more <EOS>
#
# > remembers came
# = no reply
# < came came here after george floyd and the song <EOS>
#
# > dancing finest
# = no reply
# < he he dancing <EOS>
#
# > cool america
# = no reply
# < this is america .
#
# > seems like
# = no reply
# < like like like like like <EOS>
#
# > america
# = no reply
# < this is america
#
# > use 1b
# = no reply
# < if someone speaks this in 2020 ,
#
# > got plug
# = no reply
# < i got the the <EOS>
#
# > else watched
# = no reply
# < who else is watching this in 2020
#
# > america's dark
# = no reply
# < he is <EOS>
#
# > sadly still
# = no reply
# < this is still the <EOS>
#
# > almost 2
# = no reply
# < 2 27 the kids wearing <EOS>
#
# > think music
# = no reply
# < this music video has a masterpiece .
#
# > god feels
# = no reply
# < my god i this <EOS>
#
# > remix better
# = no reply
# < this is is the <EOS>
#
# > always come
# = no reply
# < i come back to this <EOS>
#
# > subscribe pls
# = no reply
# < yeah this is a masterpiece .
#
# > people saying
# = no reply
# < people are saying that he predicted the <EOS>
#
# > comment
# = no reply
# < this is the the <EOS>
#
# > someone please
# = no reply
# < can someone explain to tell me that this
#
# > facts
# = no reply
# < i'm saw it <EOS>
#
# > else watch
# = no reply
# < who else is watching this in 2020 ?
#
# > im glad
# = no reply
# < im am i the only one i the the <EOS>
#
# > imagine song
# = no reply
# < imagine this this song song song  <EOS>
#
# > nigga aaron
# = no reply
# < this is the the <EOS>
#
# > song gives
# = no reply
# < this song is song song song song <EOS>
#
# > think music
# = no reply
# < this music video has a masterpiece .
#
# > like way
# = no reply
# < i like like like this song <EOS>
#
# > love everyone
# = no reply
# < i just came here after george floyd
#
# > never noticed
# = no reply
# < i never never noticed the the <EOS>
#
# > bunch fuckin
# = no reply
# < the * *
#
# > represent like
# = no reply
# < its like like like this song <EOS>
#
# > can't believe
# = no reply
# < i can't believe this guy in 2020 <EOS>
#
# > 2 years
# = no reply
# < 2 years later and this is still <EOS>
#
# > meme thats
# = no reply
# < this is a continent <EOS>
#
# > almost 2
# = no reply
# < 2 27 the kids wearing <EOS>
#
# > yup still
# = no reply
# < i still still get it . <EOS>
#
# > like way
# = no reply
# < i like like like this song <EOS>
#
# > wow talk
# = no reply
# < wow i have to see this song <EOS>
#
# > dude moved
# = no reply
# < the the are the <EOS>
#
# > dislikes police
# = no reply
# < the dislikes are from from the
#
# > shit still
# = no reply
# < this is still still america <EOS>
#
# > needs china
# = no reply
# < https //www . .
#
# > omg sooo
# = no reply
# < omg , this video has been be a whole continent
#
# > true music
# = no reply
# < this is is the the is <EOS>
#
# > church people
# = no reply
# < why people people people people people the <EOS>
#
# > another video
# = no reply
# < this is the video the .
#
# > america whites
# = no reply
# < this is america .
#
# > time watching
# = no reply
# < watching watching this in 2020
#
# > always relevant
# = no reply
# < this is so relevant relevant now <EOS>
#
# > cars mean
# = no reply
# < what i the the <EOS>
#
# > song still
# = no reply
# < this song is still <EOS>
#
# > song aged
# = no reply
# < this song aged like the song <EOS>
#
# > used intro
# = no reply
# < he used to an ak but he is a song <EOS>

# %%
#Run below two lines (in google colab), installation steps to get .pdf of the notebook

# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pandoc is already the newest version (1.19.2.4~dfsg-1build4).
# texlive is already the newest version (2017.20180305-1).
# texlive-latex-extra is already the newest version (2017.20180305-2).
# texlive-xetex is already the newest version (2017.20180305-1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.6/dist-packages (1.5)
# Requirement already satisfied: pip>=8.1.0 in /usr/local/lib/python3.6/dist-packages (from pypandoc) (19.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pypandoc) (50.3.2)
# Requirement already satisfied: wheel>=0.25.0 in /usr/local/lib/python3.6/dist-packages (from pypandoc) (0.35.1)

# %%
import subprocess
import time
# Wait for 5 minuts so that colab saves the notebook
time.sleep(5*60)
# !jupyter nbconvert --to HTML "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb"
# !jupyter nbconvert --to PDF "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb"
ipynb_address = path_to_final_project + checkpoint_folder_path
subprocess.call(["mv", "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.html", ipynb_address])
subprocess.call(["mv", "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.pdf", ipynb_address])
# Out:
# [NbConvertApp] Converting notebook /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb to HTML
# [NbConvertApp] Writing 527764 bytes to /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.html
# [NbConvertApp] Converting notebook /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb to PDF
# [NbConvertApp] Writing 199998 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 169823 bytes to /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.pdf
# 0
