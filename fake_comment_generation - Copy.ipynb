# %%
# %matplotlib inline

# %%
# Test:
# Max length:
# 10
# 40
# Drop-out: 
# 0.4
# 0.7
# LSTM---->best performance
# RNN
# Compare performance between Decoder and AttnDecoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
path_to_final_project = "/content/drive/Shareddrives/Deep Learning Final Project/"
sys.path.append(path_to_final_project)
checkpoint_folder_path = "checkpoint/Reza/fake comment generation/"
encoder_checkpoint_name = "encoder-best.pth"
decoder_checkpoint_name = "decoder-best.pth"

# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# *******************************************************************************
# **Author**: `Sean Robertson <https://github.com/spro/practical-pytorch>`_
#
# This is the third and final tutorial on doing "NLP From Scratch", where we
# write our own classes and functions to preprocess the data to do our NLP
# modeling tasks. We hope after you complete this tutorial that you'll proceed to
# learn how `torchtext` can handle much of this preprocessing for you in the
# three tutorials immediately following this one.
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ::
#
#     [KEY: > input, = target, < output]
#
#     > il est en train de peindre un tableau .
#     = he is painting a picture .
#     < he is painting a picture .
#
#     > pourquoi ne pas essayer ce vin delicieux ?
#     = why not try that delicious wine ?
#     < why not try that delicious wine ?
#
#     > elle n est pas poete mais romanciere .
#     = she is not a poet but a novelist .
#     < she not not a poet but a novelist .
#
#     > vous etes trop maigre .
#     = you re too skinny .
#     < you re all alone .
#
# ... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the `sequence
# to sequence network <https://arxiv.org/abs/1409.3215>`__, in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# To improve upon this model we'll use an `attention
# mechanism <https://arxiv.org/abs/1409.0473>`__, which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -  https://pytorch.org/ For installation instructions
# -  :doc:`/beginner/deep_learning_60min_blitz` to get started with PyTorch in general
# -  :doc:`/beginner/pytorch_with_examples` for a wide and deep overview
# -  :doc:`/beginner/former_torchies_tutorial` if you are former Lua Torch user
#
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <https://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <https://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <https://arxiv.org/abs/1506.05869>`__
#
# You will also find the previous tutorials on
# :doc:`/intermediate/char_rnn_classification_tutorial`
# and :doc:`/intermediate/char_rnn_generation_tutorial`
# helpful as those concepts are very similar to the Encoder and Decoder
# models, respectively.
#
# And for more, read the papers that introduced these topics:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <https://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <https://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <https://arxiv.org/abs/1506.05869>`__
#
#
# **Requirements**

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# `This question on Open Data Stack
# Exchange <https://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages>`__
# pointed me to the open translation site https://tatoeba.org/ which has
# downloads available at https://tatoeba.org/eng/downloads - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: https://www.manythings.org/anki/
#
# The English to French pairs are too big to include in the repo, so
# download to ``data/eng-fra.txt`` before continuing. The file is a tab
# separated list of translation pairs:
#
# ::
#
#     I am cold.    J'ai froid.
#
# .. Note::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/data.zip>`_
#    and extract it to the current directory.

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# .. figure:: /_static/img/seq-seq-images/word-encoding.png
#    :alt:

# %% [markdown]
# We'll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called ``Lang`` which has word → index (``word2index``) and index → word
# (``index2word``) dictionaries, as well as a count of each word
# ``word2count`` to use to later replace rare words.

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we'll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we're filtering to sentences that translate to
# the form "I am" or "He is" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 40

def filterPair(p):
  return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -  Read text file and split into lines, split lines into pairs
# -  Normalize text, filter by length and content
# -  Make word lists from sentences in pairs

# %%
def sentences_preprocessing(panda_dataset, header_com, header_reply):

  # all this would do is remove rows if elements were missing in any of the columns. 
  panda_dataset = panda_dataset.dropna()

  #remove \r (this is where you are running into vocabulary problems.)
  panda_dataset = panda_dataset.replace(to_replace=r'\r', value='', regex=True)

  #remove \n (this is where you are running into vocabulary problems.)
  panda_dataset = panda_dataset.replace(to_replace='\n', value='', regex=True)

  #convert pandas to list
  list_dataset = np.transpose([panda_dataset[header_com],panda_dataset[header_reply]]).tolist()
  return list_dataset, panda_dataset

# %%
import pandas as pd
import numpy as np

TRAINING_CSV = 'Childish Gambino - This Is America (Official Video)_refined.csv'
VALIDATION_CSV = 'Childish Gambino - This Is America (Official Video)_validation_comments_top_n.csv'

# %%
training_raw_data = pd.read_csv(path_to_final_project+'data/'+TRAINING_CSV, error_bad_lines=False, encoding='utf-8-sig')
training_raw_data.head()
# Out:
#                                     no_space_comment  ... first_2_words_in_no_space_comment
# 0  donald glover jack of all trades , master of a...  ...                     donald glover
# 1  no one \r \r \r \r \r \r\r\r\n \r \r \r \r \r ...  ...                            no one
# 2  me brings bulletproof shield to school \r \r \...  ...                         me brings
# 3                     2020 someone ? very niceee ! !  ...                      2020 someone
# 4  childish gambino 'shoots someone' " this is am...  ...                  childish gambino
#
# [5 rows x 6 columns]

# %%
test_raw_data = pd.read_csv(path_to_final_project+'data/'+VALIDATION_CSV, error_bad_lines=False, encoding='utf-8-sig')
test_raw_data.head()
# Out:
#                                   Validation Comment  ... first_2_words_in_Validation Comment
# 0  at the current state , we can do anything in a...  ...                              at the
# 1  i miss donald as troy in community when he lef...  ...                              i miss
# 2       when he said " this is america " i felt that  ...                             when he
# 3       love him or hate him , hes telling the truth  ...                            love him
# 4  when the church people were singing i heard " ...  ...                            when the
#
# [5 rows x 4 columns]

# %%
training_data, df_training = sentences_preprocessing(training_raw_data, 'first_2_keywords_in_no_space_comment' , 'no_space_comment')
# training_data, df_training = sentences_preprocessing(training_raw_data, 'first_2_words_in_no_space_comment' , 'no_space_comment')
print(np.shape(training_data))
df_training.head()
# Out:
# (5736, 2)
#                                     no_space_comment  ... first_2_words_in_no_space_comment
# 0  donald glover jack of all trades , master of a...  ...                     donald glover
# 1  no one             childish gambinos spine rig...  ...                            no one
# 2  me brings bulletproof shield to school       t...  ...                         me brings
# 3                     2020 someone ? very niceee ! !  ...                      2020 someone
# 4  childish gambino 'shoots someone' " this is am...  ...                  childish gambino
#
# [5 rows x 6 columns]

# %%
test_data, df_test = sentences_preprocessing(test_raw_data, 'first_2_keywords_in_Validation Comment', 'Validation Comment')
# test_data, df_test = sentences_preprocessing(test_raw_data, 'first_2_words_in_Validation Comment', 'Validation Comment')
print(np.shape(test_data))
df_test.head()
# Out:
# (340, 2)
#                                   Validation Comment  ... first_2_words_in_Validation Comment
# 0  at the current state , we can do anything in a...  ...                              at the
# 1  i miss donald as troy in community when he lef...  ...                              i miss
# 2       when he said " this is america " i felt that  ...                             when he
# 3       love him or hate him , hes telling the truth  ...                            love him
# 4  when the church people were singing i heard " ...  ...                            when the
#
# [5 rows x 4 columns]

# %%
  # #add space between words and some character
  # panda_dataset = panda_dataset.replace(to_replace=r':', value=':', regex=True) 
  # panda_dataset = panda_dataset.replace(to_replace=r',', value=' ,', regex=True) 
  # panda_dataset = panda_dataset.replace(to_replace=r'\'', value=' \'', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\`', value=' \`', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\.', value=' .', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\(', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\)', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\[', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\]', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\{', value='( ', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\}', value=' )', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\?', value=' ?', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace=r'\!', value=' !', regex=True)
  # #remove asteriks
  # panda_dataset = panda_dataset.replace(to_replace=r'\*', value='', regex=True)
  # panda_dataset = panda_dataset.replace(to_replace='\n', value=' \n ', regex=True)
  # #remove some repetitive spaces 
  # space = ' '
  # for i in range(10):
  #   space +=' '
  #   panda_dataset = panda_dataset.replace(to_replace=space, value=' ', regex=True) #add space after \n

# %%
# This gets me the data trimmed so that I can create the vocabulary comparison
def prepare_data_vocab(comment_reply, reverse=False):
    pairs = filterPairs(comment_reply) 
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    input_sentence = [i[0] for i in pairs]
    output_sentence = [i[1] for i in pairs]

    return input_sentence, output_sentence

# %%
print("########### Training Set ###########")
input_sentence, output_sentence = prepare_data_vocab(training_data, True)

print("\n","########### Test Set ###########")
test_input_sentence, test_output_sentence = prepare_data_vocab(test_data, True)
# Out:
# ########### Training Set ###########
# Trimmed to 4958 sentence pairs
# Counting words...
#
#  ########### Test Set ###########
# Trimmed to 339 sentence pairs
# Counting words...

# %%
import itertools
def unique(list1): 
      
    # insert the list to the set 
    list_set = set(list1) 
    # convert the set to the list 
    unique_list = (list(list_set))
    
    return unique_list

def top_n_words(input_sentence):

    words = []
    for comment in input_sentence:
        temp = comment.split()
        words.append(temp)
                     
    unique_word_list = list(itertools.chain(*words))
    
    unique_word_list = unique(unique_word_list)
    
    return unique_word_list

# %%
print("########### Training Set ###########")
unique_word_list_train = top_n_words(input_sentence)
print(len(unique_word_list_train))
print(unique_word_list_train)
print("\n","########### Test Set ###########")
unique_word_list_test = top_n_words(test_input_sentence)
print(len(unique_word_list_test))
print(unique_word_list_test)
# Out:
# ########### Training Set ###########
# 2166
# ['wouldnt', 'brazilian', 'amrica', 'americas', 'triping', 'peice', 'million', 'updated', 'jhope', 'littearly', 'jokes', 'soo', 'posted', 'piss', 'four', 'eat', 'who`s', 'single', 'heart_suit_selector', 'silence', 'fake', '100%', 'ignoring', '25', 'anything', 'terrible', 'quite', 'boomers', 'us', 'accuracy', 'protesters', 'meant', 'thumbnail', 'barnes-', 'ouugjhjjsdj', 'legit', 'janitor', 'sir', 'holy', 'ak47s', 'injured', 'describe', 'guessed', 'creeped', 'everybady', 'jacob', 'discovered', 'irony', 'understand', 'sending', 'cruise', 'may', 'production', 'live', 'truth', 'differently', 'first', 'clue', 'powerfully', 'rap', 'bit', 'nome', 'hot', 'confess', 'proved', 'sometimes', 'media', 'friend', 'color', 'medium_light_skin_tone', '701k', 'russia', 'musyc', 'shirtless', 'wanted', 'crying', 'rate', 'marry', 'early', 'gwara', 'bunch', '26', 'biden/harris', 'queen', 'go', 'parece', 'keep', 'north', 'holy-', 'proof', 'predictions', 'diss', 'regional_indicator_symbol_letter_a', 'type', 'freedom', 'joo', 'change', 'taking', 'gambino', 'give', 'united', 'turn', 'anonymous', 'restriced', "'murica", 'seeing', 'blunt', 'please', 'sounds', 'brother', 'joker', 'murders', 'seventeen', "that's", 'nice', 'blakes', 'era', 'always', 'turkey', 'pov', 'ray', 'neighbors', 'kyle', 'insert', 'resembles', 'though', 'advertised', '15-18', 'uncalled', 'pile', 'fuckin', 'muslim', 'view', '80%', 'suppose', 'pirdect', 'sure', '70%people', 'lost', 'hapenned', 'blaks', 'try', 'bahahaha', 'squad', 'relieved_face', 'pathetic', 'corona', 'worse', 'zombie', '2years', 'yellow', '700', 'news', 'si', 'lecrae', 'loves', '7th', 'equal', 'randomly', 'randy', '10', 'liked', 'fuking', 'regards', "y'all", 'jump', 'hi', '40', '9cm', 'mute', 'went', 'justice', 'fuckthepolice', 'hypocrisy', 'baba', 'recoil', 'breath', 'honest', 'ak', 'aksking', 'unironically', '98%', 'mom', "george's", 'pants', 'disliked', 'silent', 'atcually', 'dirty', 'idc', 'easily', 'fucking', 'profound', 'chier', '714', 'mass', 'myopic', 'handled', 'ffff', 'asian', 'hearing', 'peaceful', 'coolest', 'respect', '22', 'millions', 'perfectly', 'yknow', '1st', 'americans', 'serie', 'singlehandedly', 'que', '90%', '99%', 'grinning_face_with_sweat', 'putting', 'referring', 'turned', 'wake', ';', 'meu', '5g', 'appear', 'letting', 'copied', 'reminds', 'shyca', 'obama', 'chaotic', 'stay', 'offence', 'eyed', 'explains', '15', 'continues-', 'realize', 'relating', 'controversial', 'tenet', 'hitdiferent', 'america;', 'usa', '02', '706k', 'anybodys', 'genius', 'cod', 'different', 'realy', 'dancing', 'speaks', 'policeman', 'cause', 'warn', 'foresee', 'men', 'freaking', 'everyone', 'peacefully', 'crap', '+', 'recommended', 'propaganda', 'treat', 'moved', 'innocent', 'really', 'retarded', 'named', '53', 'election', 'ther', 'love', 'dam', 'pistol', 'gotta', 'physic', 'conecto', 'sit', 'national', 'blacky', '24/7', 'interviewer', 'shoud', 'highest', 'confused', 'anyway', 'pedophile', 'gray', 'getting', 'aim', 'wish', 'um', 'wtf', 'cycle', 'wants', 'welcome', 'trust', 'basically', 'poc', '47', '704m', 'dream', 'fk', 'finally', 'medium_dark_skin_tone', 'defending', 'average', 'underprivileged', 'hows', 'vibin', 'anthem', 'ahora', 'repeat', 'breaking', 'relevance', 'heck', 'orleans', "african-american's", 'symbolism', 'unhealthy', 'thousand', 'waited', 'buenara', '2', 'matters', 'flody', 'fuck', 'hehe', '57', 'loses', 'ooff', 'legal', 'phillipines', 'notices', 'attacks', 'body', 'racismo', 'reporter', 'footage', 'going', 'time', 'current', 'becoming', 'bidens', '35', 'murdering', 'dark', 'cared', '-tell', 'anyone', 'oh', 'lookin', 'rasicst', 'without', 'telling', 'flying', 'rest', 'describes', 'crappy', 'name', 'depicting', 'releases', 'forget', 'officially', 'wierdest', 'kenosha', 'described', 'b-but', 'meh', 'petition', 'isnt', 'coming', 'couldnt', 'wearing', 'original', 'rt', 'theres', 'afrika', 'biggest', 'blow', 'yt', 'chirch', 'goosebumps', 'ridiculous', 'lift', 'seem', 'sad', 'actor', 'headline', 'government', 'forn ...
#
#  ########### Test Set ###########
# 405
# ['cried', 'bts', 'ee', 'believe', 'whos', "i'm", 'amrica', 'changed', 'listens', 'music', 'bet', 'another', 'remember', 'screams', 'everyday', 'racist', 'community', 'im', 'hate', 'wow', 'posture', 'perfect', 'creation', 'heard', 'creative', 'hella', 'damn', 'likes', "america's", 'dope', 'us', 'find', 'reaction', 'anytime', 'anybody', 'pretty', 'legit', 'brothers', 'guys', 'comments', 'hidden', 'understand', 'background', 'dance', '8', 'gives', 'check', 'headphones', 'young', 'truth', 'first', 'world', 'maga', 'acted', 'choreography', 'goes', 'better', 'watch', 'opinion', 'lets', "can't", 'russia', 'occurred', 'yep', "he'll", 'met', 'bunch', 'since', 'church', 'dad', 'spider-man', 'go', 'pumped', 'things', 'black', 'proof', 'subscribe', 'omg', 'diss', 'hitting', 'send', 'hello', 'after', 'found', 'saw', 'scarily', "'murica", 'please', 'run', 'mind', 'friends', 'use', "that's", 'always', 'masterpiece', 'two', 'trump', 'though', 'thought', 'social', 'rlly', 'disses', 'kill', 'told', 'canadians', 'third', 'fuckin', 'said', 'uu', 'makes', 'crazy', 'hes', 'lost', 'war', 'maybe', 'kinda', 'seems', 'aged', 'stupid', 'iran', 'iconic', 'someone', 'take', 'pick', 'else', 'puts', 'story', 'mean', 'predict', 'abed', 'song', 'make', 'serious', 'videos', 'think', 'went', 'plug', 'expecting', 'listen', 'see', 'glad', 'paper', 'best', 'fucking', 'much', 'gonna', 'must', 'flyingkitty', 'hearing', 'aaron', 'represent', 'happy', 'tea', 'beginning', 'trades', 'os', 'years', 'reason', 'message', 'riot', 'one', 'person', 'karen', 'sudden', ';', 'american', 'comment', 'thank', 'reminds', 'simply', 'state', 'hum', 'underrated', 'based', 'realize', 'face', 'amazing', 'day', 'genius', 'yeah', 'miracle', 'dancing', 'speaks', 'marshall', 'actually', 'forever', 'homecoming', 'lmaoo', 'true', 'everyone', 'patrick', 'obsessed', 'saying', 'moved', 'lando', 'childish', 'yup', 'troy', 'really', 'wonder', 'taken', '700m', 'cars', 'started', 'dislikes', 'murder', 'love', 'many', 'start', 'gotta', 'days', 'youtube', 'wish', '2018', 'flex', 'wait', 'know', 'depression', 'replace', 'play', 'touch', 'dang', 'africa', 'hear', 'wants', 'recommendation', 'dudes', 'never', 'dream', 'dude', 'still', 'idk', 'second', 'hell', 'long', 'facts', 'minute', 'right', '2', 'interesting', 'intro', 'fuck', 'commentary', 'shit', 'embarrassed', 'billion', 'darkest', 'gon', 'talk', 'planet', 'virus', 'mask', 'u', 'open', 'going', 'like', 'time', 'current', 'came', 'playing', 'way', 'watching', 'hard', 'dark', 'tune', 'europe', 'anyone', '1b', 'j', 'telling', 'flying', 'describes', 'noticed', 'racism', 'free', 'canada', 'away', 'people', 'hey', 'cool', 'petition', 'representation', 'coming', 'party', "he's", 'wearing', 'filming', 'ask', "there's", 'moral', 'blows', 'songbecause', 'sad', 'concept', 'used', 'looting', 'wear', 'well', 'w', '1', "ain't", 'fitting', 'n', 'notice', 'ft', 'deep', 'worst', 'kind', 'left', 'future', 'amerca', 'kitty', '2021', 'needs', 'year', 'asians', 'facial', 'relevant', 'whites', 'movements', 'lives', 'messy', 'kids', 'plays', 'sooo', 'surprised', 'good', 'matter', 'dislike', 'america', '5', 'sorry', 'police', 'hurts', 'guy', 'didnt', 'everytime', 'funny', 'disappointing', 'remix', 'vpn', 'watched', 'pls', 'feels', 'meme', 'lol', 'fucked', 'wrong', 'look', 'come', 'everything', 'glover', 'video', 'beautiful', 'got', 'suicide', 'dont', 'knew', 'legend', 'views', 'girlfriend', 'finest', 'imagine', 'almost', 'recommendations', 'predicted', 'decade', 'real', 'fbe', 'whole', 'brain', 'comes', 'miss', 'nigga', 'thats', "let's", 'god', 'movie', 'memes', 'fire', 'rappers', '2020', 'jack', 'cup', 'smoking', 'man', 'donald', 'even', 'yo', 'remembers', 'episode', 'white', 'stop', 'call', 'feel', 'listening', 'want', 'china', 'regret', 'describing', 'americahello', 'sadly', 'shut', 'gun', 'cant']

# %%
import csv
csv_vocab_validation = 'vocabulary_validation.csv'
save_csv_location = path_to_final_project+'data/'+csv_vocab_validation
val_comment_vocab_check = []
with open(save_csv_location, 'w', newline='', encoding='utf-8-sig') as csvfile:
    fieldnames = ['Validation Comment', 'Validation Reply']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    for sentence in test_input_sentence:
        individual_words = sentence.split()
        # print(individual_words)
        if all(item in unique_word_list_train for item in individual_words):
            val_comment_vocab_check.append(sentence)
            writer.writerow({'Validation Comment': sentence, 'Validation Reply': 'no reply'})
        else:
            continue
        
# print(val_comment_vocab_check)
print('here')
# Out:
# here

# %%
test_raw_data = pd.read_csv(save_csv_location, error_bad_lines=False, encoding='utf-8-sig') #----> change "data.csv" when the test set is ready
test_raw_data.head()
# Out:
#   Validation Comment Validation Reply
# 0      current state         no reply
# 1        miss donald         no reply
# 2       said america         no reply
# 3          love hate         no reply
# 4      church people         no reply

# %%
test_data, df_test = sentences_preprocessing(test_raw_data, 'Validation Comment', 'Validation Reply')
print(np.shape(test_data))
df_test.head()
# Out:
# (261, 2)
#   Validation Comment Validation Reply
# 0      current state         no reply
# 1        miss donald         no reply
# 2       said america         no reply
# 3          love hate         no reply
# 4      church people         no reply

# %%
def prepare_Data(comment_reply, reverse=False):
    pairs = filterPairs(comment_reply) 
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    input_sentence = Lang("comment")
    
    output_sentence = Lang("reply")

    for pair in pairs:
        # print(count)
        input_sentence.addSentence(pair[0])
        output_sentence.addSentence(pair[1])

    print("Counted words:")
    print(input_sentence.name, input_sentence.n_words)
    print(output_sentence.name, output_sentence.n_words)
    return input_sentence, output_sentence, pairs

    return input_sentence, output_sentence, pairs

print("########### Training Set ###########")
input_sentence, output_sentence, pairs = prepare_Data(training_data, True)
print(random.choice(pairs))
print("\n","########### Test Set ###########")
test_input_sentence, test_output_sentence, test_pairs = prepare_Data(test_data, True)
print(random.choice(test_pairs))
# Out:
# ########### Training Set ###########
# Trimmed to 4958 sentence pairs
# Counting words...
# Counted words:
# comment 2168
# reply 5418
# ['many black', 'but many black people hate asian lol grinning_face_with_sweat loudly_crying_face       they always slant their eyes when they see me .']
#
#  ########### Test Set ###########
# Trimmed to 261 sentence pairs
# Counting words...
# Counted words:
# comment 295
# reply 4
# ['watching flyingkitty', 'no reply']

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A `Sequence to Sequence network <https://arxiv.org/abs/1409.3215>`__, or
# seq2seq network, or `Encoder Decoder
# network <https://arxiv.org/pdf/1406.1078v3.pdf>`__, is a model
# consisting of two RNNs called the encoder and decoder. The encoder reads
# an input sequence and outputs a single vector, and the decoder reads
# that vector to produce an output sequence.
#
# .. figure:: /_static/img/seq-seq-images/seq2seq.png
#    :alt:
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence "Je ne suis pas le chat noir" → "I am not the
# black cat". Most of the words in the input sentence have a direct
# translation in the output sentence, but are in slightly different
# orders, e.g. "chat noir" and "black cat". Because of the "ne/pas"
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the "meaning" of the input sequence into a single
# vector — a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# .. figure:: /_static/img/seq-seq-images/encoder-network.png
#    :alt:

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        pretrained_emb = path_to_final_project+"wm_06.npy"
        glove=np.load(pretrained_emb)
        glove=glove.astype('float32') 
        weights = torch.from_numpy(glove)
        self.embedding = nn.Embedding.from_pretrained(weights, freeze=True)
        # self.embedding = nn.Embedding(input_size, hidden_size)
        # self.gru = nn.GRU(hidden_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        # self.rnn = nn.RNN(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# The Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ^^^^^^^^^^^^^^
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string ``<SOS>``
# token, and the first hidden state is the context vector (the encoder's
# last hidden state).
#
# .. figure:: /_static/img/seq-seq-images/decoder-network.png
#    :alt:

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        # self.gru = nn.GRU(hidden_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        # self.rnn = nn.RNN(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we'll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# ^^^^^^^^^^^^^^^^^
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# .. figure:: https://i.imgur.com/1152PYf.png
#    :alt:
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# .. figure:: /_static/img/seq-seq-images/attention-decoder-network.png
#    :alt:

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length
        pretrained_emb = path_to_final_project+"wm_06.npy"
        glove=np.load(pretrained_emb)
        glove=glove.astype('float32') 
        weights = torch.from_numpy(glove)
        self.embedding = nn.Embedding.from_pretrained(weights, freeze=True)
        # self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        # self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size)
        # self.rnn = nn.RNN(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        # output, hidden = self.gru(output, hidden)
        output, (hidden,_) = self.lstm(output, (hidden,hidden))
        # output, hidden = self.rnn(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>There are other forms of attention that work around the length
#   limitation by using a relative position approach. Read about "local
#   attention" in `Effective Approaches to Attention-based Neural Machine
#   Translation <https://arxiv.org/abs/1508.04025>`__.</p></div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_sentence, pair[0])
    target_tensor = tensorFromSentence(output_sentence, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# "Teacher forcing" is the concept of using the real target outputs as
# each next input, instead of using the decoder's guess as the next input.
# Using teacher forcing causes it to converge faster but `when the trained
# network is exploited, it may exhibit
# instability <http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf>`__.
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation -
# intuitively it has learned to represent the output grammar and can "pick
# up" the meaning once the teacher tells it the first few words, but it
# has not properly learned how to create the sentence from the translation
# in the first place.
#
# Because of the freedom PyTorch's autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# ``teacher_forcing_ratio`` up to use more of it.

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)   
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -  Start a timer
# -  Initialize optimizers and criterion
# -  Create set of training pairs
# -  Start empty losses array for plotting
#
# Then we call ``train`` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
    best_loss = 1e9

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()
    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        #saving the models
        if loss <best_loss:
          best_loss = loss
          torch.save(encoder.state_dict(), path_to_final_project + checkpoint_folder_path + encoder_checkpoint_name)
          torch.save(decoder.state_dict(), path_to_final_project + checkpoint_folder_path + decoder_checkpoint_name)

        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            evaluateRandomly(encoder, decoder,pairs,n=2)


        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ----------------
#
# Plotting is done with matplotlib, using the array of loss values
# ``plot_losses`` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_sentence, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            # decoder_output, decoder_hidden = decoder(
            #     decoder_input, decoder_hidden)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_sentence.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, pairs, seed=5, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we'll get some
# reasonable results.
#
# .. Note::
#    If you run this notebook you can train, interrupt the kernel,
#    evaluate, and continue training later. Comment out the lines where the
#    encoder and decoder are initialized and run ``trainIters`` again.

# %%
#--------> IMPORTATNT NOTE: running this block will re-write the checkpoints. Make sure to get a backup before uncommenting and training

hidden_size = 300
encoder1 = EncoderRNN(input_sentence.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_sentence.n_words, dropout_p=0.1).to(device)
# attn_decoder1 = DecoderRNN(hidden_size, output_sentence.n_words).to(device)

trainIters(encoder1, attn_decoder1, 75000, print_every=500)
# Out:
# 0m 27s (- 67m 44s) (500 0%) 5.3365
# > anyone else
# = anyone else here from call me maybe cuz it just got recommended again
# < this is <EOS>
#
# > r p
# = r . i . p george floyd . . . . this song is ruined . . .
# < this is <EOS>
#
# 0m 39s (- 48m 31s) (1000 1%) 4.7214
# > stop video
# = when you stop the video but the gunshots don't stop
# < this is . <EOS>
#
# > disslikes trump
# = disslikes from trump and that police who killed george floyd
# < this is . <EOS>
#
# 0m 51s (- 41m 50s) (1500 2%) 4.8877
# > dislikes people
# = the dislikes are the people that are the problem in america .
# < this song is the is <EOS>
#
# > way america
# = by the way , america is a continent not a country , your country is name united states of america . stop confusing and learn more abour geography !
# < this song is the is <EOS>
#
# 1m 2s (- 38m 9s) (2000 2%) 4.6546
# > try watching
# = try watching this video without sound .
# < i is the is the song the song . <EOS>
#
# > commented political
# = he not only commented on the political unrest that has been going on throughout the years , but singlehandedly predicted 2020 for us . what a visionary . i am in sheer awe . i miss him .
# < i is the is the song the song . <EOS>
#
# 1m 14s (- 35m 46s) (2500 3%) 4.5881
# > guy looks
# = this guy looks a lot like troy from community and donald glover
# < this is america <EOS>
#
# > sure president
# = for sure when the president dies ima blast this
# < this is this is america <EOS>
#
# 1m 25s (- 34m 2s) (3000 4%) 4.4928
# > nobody
# = nobody       his moves right_arrow_selector down-right_arrow_selector down-left_arrow_selector left_arrow_selector left-right_arrow_selector right_arrow_curving_left left_arrow_curving_right right_arrow_curving_up_selector right_arrow_curving_down_selector down_arrow_selector
# < i is the the song <EOS>
#
# > rly wish
# = i rly wish that the government was more careful about who we gave guns to and who is in power . there are to many evil cops out there for me to even feel secure .
# < i is the the song <EOS>
#
# 1m 36s (- 32m 59s) (3500 4%) 4.4195
# > song ain't
# = this song ain't no more relevant than when it came out . the situation in america was the same then , and it sill is now .
# < i is the is the in the <EOS>
#
# > sociology professor
# = my sociology professor introduced me to this song having me analyze it looking behind it's deeper meaning . i love this song so much
# < i is the is the the in the <EOS>
#
# 1m 47s (- 31m 56s) (4000 5%) 4.5260
# > al racismo
# = no al racismo raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone ! todos somos iguales !
# < this song is the the <EOS>
#
# > thats america
# = so thats america ?
# < this song is the the <EOS>
#
# 2m 0s (- 31m 21s) (4500 6%) 4.4111
# > song expresses
# = this song expresses the deep message of racism's relationship with america . this song is really true and displays the effect of racism . donald glover is amazing
# < this is america the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > 1 56
# = why just why 1 56
# < this is america the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 2m 13s (- 31m 8s) (5000 6%) 4.6540
# > https //www
# = https //www . youtube . com/playlist ? list=pl1k0xh3vor8vd3dyjqvt9x-nbxcsemw_k grinning_face_with_big_eyes grinning_face_with_big_eyes
# < this is america is america
#
# > song protest
# = this song should be at protest to still show this is america       the reality we live still
# < this is america is america
#
# 2m 24s (- 30m 31s) (5500 7%) 4.5682
# > else watching
# = who else is watching this in october 2020
# < the this song is <EOS>
#
# > dude guy
# = dude , this guy tried to tell the truth about america
# < the this song is <EOS>
#
# 2m 37s (- 30m 6s) (6000 8%) 4.6685
# > knew two
# = who knew two years later this song would litteraly be us
# < this song is <EOS>
#
# > black lives
# = black lives matter raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone / prides day rainbow rainbow rainbow rainbow rainbow rainbow
# < this song is <EOS>
#
# 2m 48s (- 29m 34s) (6500 8%) 4.4842
# > 1 55
# = 1 55 good aimbot . reporting
# < i is america <EOS>
#
# > funny trump
# = its funny how trump supporters use this song in theyre tiktok videos not knowing the meaning behind it
# < i is america <EOS>
#
# 3m 0s (- 29m 12s) (7000 9%) 4.5143
# > actually america
# = this is actually america #black lives matter
# < this is america is a <EOS>
#
# > brings bulletproof
# = me brings bulletproof shield to school       teacher why       me this is america
# < this is is a <EOS>
#
# 3m 12s (- 28m 50s) (7500 10%) 4.5230
# > im american
# = im not american but seeing this video become real life gives me chills .
# < this is america the . <EOS>
#
# > blasting highway
# = i was blasting this on the highway , i got pulled over skull
# < this is america is america <EOS>
#
# 3m 23s (- 28m 27s) (8000 10%) 4.3032
# > im litterally
# = im litterally comeback here just to check the comment about the american chaos right now d
# < this is a a <EOS>
#
# > 2 years
# = 2 years later and the line       " police be trippin doe " really makes sense now
# < i is a a <EOS>
#
# 3m 35s (- 28m 2s) (8500 11%) 4.3265
# > pause game
# = when you pause the game but still hears gunshots             * this is america *
# < i is the police of the
#
# > raised_fist medium_dark_skin_tone
# = raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist dark_skin_tone fuck 12 no justice no peace i cant breathe
# < this is is a <EOS>
#
# 3m 47s (- 27m 45s) (9000 12%) 4.3523
# > shouldve played
# = we shouldve played this song when we were protesting for black rights
# < this is america <EOS>
#
# > 2020 black
# = 2020 and more black victims . silence is betrayal
# < the dislikes is the <EOS>
#
# 3m 58s (- 27m 24s) (9500 12%) 4.3873
# > heart_suit_selector
# =  heart_suit_selector
# < this is the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > black lives
# = black lives matter raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone and we are the same raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist medium_light_skin_tone raised_fist light_skin_tone raised_fist
# < this is the . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 4m 10s (- 27m 11s) (10000 13%) 4.6535
# > better https
# = this is better https //www . youtube . com/watch ? v=yuwq_abie_s
# < this is the the same of the same . . . .
#
# > amazing way
# = an amazing way to portray social and political indifference and racism .
# < this is the the same of the same . . . . . .
#
# 4m 23s (- 27m 1s) (10500 14%) 4.5219
# > countries hating
# = countries hating merica       me 1 56
# < this is america <EOS>
#
# > raised_fist dark_skin_tone
# = raised_fist dark_skin_tone this is america . . .
# < this is america <EOS>
#
# 4m 35s (- 26m 45s) (11000 14%) 4.4126
# > gringos understand
# = gringos understand that america is not a country america is a continent ignorant latin america exists north and south america giles i hope you know this ignorant fucking shit
# < this is the  <EOS>
#
# > 2020 predicted
# = this is 2020 he predicted it .
# < this is the people who disliked this song is the  <EOS>
#
# 4m 47s (- 26m 27s) (11500 15%) 4.2809
# > get killed
# = i don't get it he killed them for no reason
# < this is a this is america <EOS>
#
# > dislikes people
# = the dislikes are from people who dont understand the song
# < this is a this is america <EOS>
#
# 4m 59s (- 26m 12s) (12000 16%) 4.2844
# > crazy song
# = it's crazy how this song is relevant still and could be applied to other events dating back decades . it seems like racism keeps getting worse and worse every year i swear .
# < this is america <EOS>
#
# > r p
# = r . i . p george floyd the man found with fentanyl and methamphetamine in his system he aint no fucking saint people . so now we raid peoples businesses because this is america
# < this is america <EOS>
#
# 5m 11s (- 25m 59s) (12500 16%) 4.3818
# > song protest
# = this song should be at protest to still show this is america       the reality we live still
# < this song is america  <EOS>
#
# > wonder ppl
# = i wonder what ppl from other countrys think of this song ? thinking_face thinking_face thinking_face thinking_face
# < this is a  <EOS>
#
# 5m 24s (- 25m 46s) (13000 17%) 4.3592
# > else black
# = who else here after the black lives matter protests and george floyd's death
# < i is this this the this  . . .
#
# > guy looks
# = this guy looks a lot like troy from community and donald glover
# < this is this this the  . .
#
# 5m 35s (- 25m 30s) (13500 18%) 4.2312
# > fellow protesters
# = to all my fellow protesters wear goggles and a mask . do whatever you can ! ! no justice no peace ! ! kissing_face_with_closed_eyes middle_finger
# < this is is the . . . .  <EOS>
#
# > building would
# = that building would make a great shooting range
# < this is the the . . . .  <EOS>
#
# 5m 47s (- 25m 14s) (14000 18%) 4.1045
# > america
# = this is america "       no , this is hell
# < this is america america <EOS>
#
# > sza cameo
# = that sza cameo hit different today .
# < the fact that this is <EOS>
#
# 5m 59s (- 25m 1s) (14500 19%) 4.1650
# > let's remember
# = let's just remember that blacklivesmatter has been around longer then 2020 , don't start caring now just cuz you in yo damn house
# < i is here this this this video     <EOS>
#
# > fact americans
# = the fact it's only americans who like and indians who dislike it is great haha lol
# < i is here this this this video          <EOS>
#
# 6m 11s (- 24m 45s) (15000 20%) 4.1858
# > one hearing
# = am i the only one hearing both this is america and this is a miracle ? ive been thinking about this for 2 years . or im just looking for another piece of hidden sense and irony
# < this is the this . <EOS>
#
# > fires ak
# = fires ak 3 times       10 bodies hit the floor
# < this is is <EOS>
#
# 6m 22s (- 24m 29s) (15500 20%) 4.1038
# > someone lead
# = someone lead a protest while blasting this please-
# < i is this is . <EOS>
#
# > thought kanye
# = this is what i thought kanye west's music would evolve to when he created jesus walks
# < i is this the . the <EOS>
#
# 6m 34s (- 24m 16s) (16000 21%) 4.3298
# > proud american
# = proud to not be american regional_indicator_symbol_letter_a regional_indicator_symbol_letter_u
# < i dont this this . . this . . <EOS>
#
# > 2019 america
# = 2019 this is america             2020 this is cororica
# < this is america .
#
# 6m 47s (- 24m 6s) (16500 22%) 4.4256
# > 45 presidents
# = out of 45 presidents , only one black president ever , that too after 230+ years .       * this is america *
# < this is
#
# > black people
# = black people in america are too gangstar
# < i dont know this this
#
# 6m 59s (- 23m 51s) (17000 22%) 4.2669
# > song gives
# = this song gives me shivers now , because of whats happening in america
# < this song is is america <EOS>
#
# > fucking clown
# = you fucking clown .
# < this is .  <EOS>
#
# 7m 11s (- 23m 36s) (17500 23%) 3.9974
# > rate song
# = rate this song on a scale 1 to america .             me this is america .
# < this is this song is <EOS>
#
# > song cool
# = the song is cool but the video also fuck you
# < this song is song <EOS>
#
# 7m 22s (- 23m 22s) (18000 24%) 4.1282
# > u realize
# = when u realize this is the guy who voice marshall lee in adventure time *
# < i else the this this is <EOS>
#
# > troy abed
# = troy and abed in the morning . . .
# < i else the this <EOS>
#
# 7m 34s (- 23m 8s) (18500 24%) 4.1731
# > america imagine
# = if that is america imagine latin america . we are helpless .
# < this is america . <EOS>
#
# > 1 56
# = 1 56 what just happned hushed_face neutral_face
# < i hate the this  <EOS>
#
# 7m 46s (- 22m 55s) (19000 25%) 4.2085
# > viewed video
# = this is the most viewed video 722 , 910 , 213 views
# < this is this this  this is america <EOS>
#
# > cops answer
# = the cops are not the answer . . . . they are the problem #ripgeorgefloyd
# < i am that he is  <EOS>
#
# 7m 57s (- 22m 39s) (19500 26%) 4.1378
# > predicted 2020
# = he predicted 2020 two years before it happened
# < this is is <EOS>
#
# > made video
# = made this video at the wrong time . wow its like he predicted it
# < this is this is  <EOS>
#
# 8m 9s (- 22m 26s) (20000 26%) 3.9697
# > really real
# = is that really a real man 0 53
# < this is like this is <EOS>
#
# > supposed funny
# = is this supposed to be funny
# < this is the the  <EOS>
#
# 8m 21s (- 22m 14s) (20500 27%) 4.0303
# > shot church
# = why you shot them church peopel
# < i cant are the the . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# > love america
# = love you america sparkling_heart
# < i cant like this is america . <EOS>
#
# 8m 33s (- 22m 0s) (21000 28%) 4.0742
# > cant believe
# = i cant believe they actually call this crap music !
# < i cant believe this song is <EOS>
#
# > guy atcually
# = did that guy atcually shot him ?
# < this is i the this in the song <EOS>
#
# 8m 46s (- 21m 50s) (21500 28%) 4.3468
# > like glimpse
# = it's like he has a glimpse of the future .       come today and look to america .
# < this is is is . <EOS>
#
# > 2 57
# = 2 57 that is a fake cigarette , but okay . . .
# < 2 28 the .  ! this is . <EOS>
#
# 8m 57s (- 21m 35s) (22000 29%) 3.9890
# > kid school
# = kid in school i didn't do my homework do not snitch                   other students 1 40
# < i is this <EOS>
#
# > else got
# = who else got creeped out at the end when you could only see his eyes and mouth .
# < i cant here after the this song <EOS>
#
# 9m 9s (- 21m 22s) (22500 30%) 4.0357
# > hell song
# = what the hell , this song makes no sense "       * me 2 years later realize the non sense of this song is the point of it
# < this is the song song is the the <EOS>
#
# > cant wait
# = cant wait until childish gambino sing this is world
# < this is the is is  <EOS>
#
# 9m 22s (- 21m 11s) (23000 30%) 4.0823
# > canada
# = this is canada
# < this is is <EOS>
#
# > end gives
# = the end gives me chills every damn time .
# < this is is <EOS>
#
# 9m 34s (- 20m 58s) (23500 31%) 3.9933
# > america third
# = america a third world country with a gucci belt .
# < this is america
#
# > black live
# = black live matter , i'm white , fuck these cops
# < i is the  <EOS>
#
# 9m 47s (- 20m 47s) (24000 32%) 4.1801
# > good music
# = this is not a good music for the humans with color black
# < this is this
#
# > usa fucked
# = usa is a fucked up country
# < this is is
#
# 9m 59s (- 20m 35s) (24500 32%) 3.9327
# > stupid song
# = this stupid song ever
# < this song is the song is  . <EOS>
#
# > sucks
# = this sucks
# < this is the  . <EOS>
#
# 10m 11s (- 20m 22s) (25000 33%) 4.1590
# > imagine super
# = imagine being a super successful and rich black celebrity complaining and acting like they're suffering in one of the best countries to live in .
# < i be like he predicted the future
#
# > make another
# = he should make another one to show what is going on in america today
# < this is is is <EOS>
#
# 10m 23s (- 20m 10s) (25500 34%) 4.0592
# > usa certainly
# = usa certainly the most misunderstood country in the world . . . these millionaries are " oppressed " maybe black americans should see how the rest of the world is treated
# < i . the . <EOS>
#
# > i'm see
# = i'm here to see what the song actually sounds like due to tik tok
# < i are the the <EOS>
#
# 10m 35s (- 19m 57s) (26000 34%) 4.0490
# > really need
# = we really need this song right now
# < i feel like the this this this <EOS>
#
# > america see
# = not from america but to see what's happening there is extremely devastating , my prayers are with you
# < america is america <EOS>
#
# 10m 47s (- 19m 44s) (26500 35%) 3.8979
# > car park
# = if this is a car park , why are there no cars *
# < this is is <EOS>
#
# > childish gambino
# = childish gambino this is america       me cancel my trip to america       virus am i the reason ?
# < childish gambino is the future <EOS>
#
# 10m 59s (- 19m 31s) (27000 36%) 3.8182
# > dude guy
# = dude this guy is benefiting for every great part of america and he has the nerve to make a song like this this piece of shit move to nigeria or somewhere
# < this is this the song song <EOS>
#
# > u buy
# = when u can buy an ak but u cant buy an chocolate egg , this is america
# < i is this the  <EOS>
#
# 11m 12s (- 19m 20s) (27500 36%) 4.0670
# > know scary
# = you know this is scary for me a cop was watching me because i was the only black person im the park weary_face confounded_face
# < i know the the <EOS>
#
# > childish gambino
# = childish gambino this is america       me this is the world
# < childish gambino * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# 11m 25s (- 19m 9s) (28000 37%) 4.1918
# > unarmed white
# = more unarmed white men died by cops in 2019 than unarmed black men . pog
# < i dont know that this is america <EOS>
#
# > video clip
# = this video clip turn to the reality *
# < this video is the future <EOS>
#
# 11m 37s (- 18m 58s) (28500 38%) 4.1125
# > predicted riot
# = predicted riot ?
# < he predicted the future <EOS>
#
# > yes america
# = yes this is america
# < this is america . . . <EOS>
#
# 11m 49s (- 18m 44s) (29000 38%) 3.7892
# > gambino
# = this is gambino
# < this is is is <EOS>
#
# > first kill
# = the first kill looked fake
# < this is is <EOS>
#
# 12m 1s (- 18m 32s) (29500 39%) 3.8852
# > exchange student
# = exchange student expectation america is going to be so fu-             * reality *
# < he predicted the future <EOS>
#
# > definitely good
# = definitely good for the year of 2020 , again , with the protest .
# < this is the the <EOS>
#
# 12m 12s (- 18m 19s) (30000 40%) 3.8643
# > kill person
# = did he kill a person for this
# < the is <EOS>
#
# > really represents
# = this really represents america and all of the tragedy
# < this is a this this <EOS>
#
# 12m 24s (- 18m 6s) (30500 40%) 3.7893
# > listening song
# = listening to this song because nobody wants to wear masks and the american economy is gonna go under
# < the is song song the
#
# > everyone gonna
# = is everyone gonna just ignore how sexy donald is looking in this dad bod
# < this is a a this
#
# 12m 36s (- 17m 54s) (31000 41%) 4.0899
# > realized white
# = i just realized that the only white people in this video are chasing him at the end
# < i know the the <EOS>
#
# > fun games
# = all fun and games till this comes true
# < i know the this <EOS>
#
# 12m 49s (- 17m 42s) (31500 42%) 3.9095
# > fuck song
# = fuck this song
# < i this this song song <EOS>
#
# > even 2
# = even 2 years later the song still match with actuality
# < 2 2 2 years ago this song <EOS>
#
# 13m 1s (- 17m 29s) (32000 42%) 3.9272
# > 2 27
# = at 2 27 the kids are wearing face masks .
# < 2 28
#
# > america fall
# = america will fall down soon
# < this is america america
#
# 13m 13s (- 17m 17s) (32500 43%) 3.9141
# > people already
# = people already wearing covid masks in 2018 ? 2 29
# < people are people america is <EOS>
#
# > believe america
# = believe or not america still better than many countries where peoples disappear there simply and easily for a years and the decorators of these countries supported by us and europe
# < this is america america , the is america <EOS>
#
# 13m 25s (- 17m 4s) (33000 44%) 4.0554
# > hate america
# = i hate america
# < this is america america .
#
# > love america
# = love you america sparkling_heart
# < i cant this this this the future
#
# 13m 36s (- 16m 52s) (33500 44%) 3.8857
# > garbage
# = this is garbage
# < this is <EOS>
#
# > hits different
# = this hits different in 2020
# < i love how this is still america <EOS>
#
# 13m 48s (- 16m 39s) (34000 45%) 3.9245
# > yes pretty
# = yes , that was pretty childish .
# < this is is a . <EOS>
#
# > ill surprised
# = ill be surprised if someone says i survived 2020
# < raised_fist dark_skin_tone raised_fist raised_fist raised_fist <EOS>
#
# 14m 1s (- 16m 27s) (34500 46%) 3.8823
# > needs stop
# = this needs to stop no matter what skin is it
# < this is how many dislikes are from america . <EOS>
#
# > cried seeing
# = i cried seeing this video a second time . what's wrong with this country ? ! do they still in the middle ages or what . . . . this is really really sad what's going on there .
# < this is are from <EOS>
#
# 14m 15s (- 16m 17s) (35000 46%) 3.9662
# > dont like
# = i dont like this song
# < i like like this is <EOS>
#
# > song hitting
# = this song do be hitting different because of the recent events going on . . .
# < this song is so more and more black people <EOS>
#
# 14m 27s (- 16m 5s) (35500 47%) 3.9330
# > good song
# = good song but whats with that dance ?
# < this is this song song song <EOS>
#
# > like song
# = it's like this song was written about usa nowadays .
# < this like this song is like a song <EOS>
#
# 14m 40s (- 15m 53s) (36000 48%) 3.8418
# > went subtle
# = this went from a subtle reflection of american culture to describing whats happening outside
# < this is not to this . . .
#
# > claim 1b
# = claim your before 1b ticket here ! backhand_index_pointing_down       admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector admission_tickets_selector       oh and like so more people can see
# < i can't is
#
# 14m 52s (- 15m 41s) (36500 48%) 3.9086
# > choir shooting
# = choir shooting = charleston sc church shooting by dylan roof . #thisisamerikkka
# < i know the the the the <EOS>
#
# > many bad
# = when you have this many bad apples , the problem is in the orchard .
# < i is that this song is the <EOS>
#
# 15m 4s (- 15m 28s) (37000 49%) 3.8178
# > 21 singing
# = is 21 singing the ad libs ?
# < why does this is the
#
# > almost prophetic
# = this is almost prophetic in nature . especially the pale horse rider . the pandemic in the midst of riots ?
# < this is to . <EOS>
#
# 15m 16s (- 15m 16s) (37500 50%) 3.8981
# > police trippin'
# = police be trippin' now "
# < 0 52 i know i .
#
# > ending looks
# = the ending looks like a scene from a jordan peele movie
# < i you just a this  this is america <EOS>
#
# 15m 29s (- 15m 4s) (38000 50%) 3.9675
# > man shot
# = is the man that you shot dead ?
# < i he was the the
#
# > 2 28
# = 2 28 somebady explain why they wearing mask face_with_medical_mask , if this 2 yrs ago
# < 2 years later and the
#
# 15m 41s (- 14m 52s) (38500 51%) 3.9560
# > song/ video
# = what does this song/ video mean someone explain in one sentence please
# < the fact that this video is in the <EOS>
#
# > song related
# = if the song was related to corona virus , then this would be 100% accurate
# < this song is song <EOS>
#
# 15m 53s (- 14m 40s) (39000 52%) 3.8553
# > amo esse
# = amo esse clipe . . . toda vez que vejo ele encontro algum novo significado clapping_hands medium_light_skin_tone clapping_hands medium_light_skin_tone clapping_hands medium_light_skin_tone
# < this is a . to .  <EOS>
#
# > sad theres
# = its sad that theres almost one million dislikes
# < i sad to this to america . .  <EOS>
#
# 16m 6s (- 14m 28s) (39500 52%) 3.8305
# > really shot
# = is he really shot this guy ?
# < i really really good in america . <EOS>
#
# > music
# = this is not music
# < this is america <EOS>
#
# 16m 18s (- 14m 16s) (40000 53%) 3.6814
# > else wwiii
# = who else before wwiii             backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down backhand_index_pointing_down
# < who else is here after the the <EOS>
#
# > matter happens
# = no matter what happens tomorrow , we all screwed
# < i dont get the the <EOS>
#
# 16m 31s (- 14m 4s) (40500 54%) 3.7460
# > accurate god
# = how accurate this was god forbid the last part
# < this is a the  this is <EOS>
#
# > whats covid
# = whats with the covid masks @2 29 ?
# < why is this the
#
# 16m 43s (- 13m 52s) (41000 54%) 3.8587
# > america
# = t is america
# < this is america <EOS>
#
# > like think
# = i like how all i think of is troy barnes cause i finally just watched communtiy
# < i like like like i like like america <EOS>
#
# 16m 56s (- 13m 40s) (41500 55%) 3.7852
# > 1 09
# = 1 09 guy on the right looks like will
# < this is
#
# > im george
# = im here after george floyd was murdered by minneapolis cops . may he rest in justice .
# < im sorry but i am i to
#
# 17m 9s (- 13m 28s) (42000 56%) 3.8704
# > wearing medical
# = they wearing medical masks before corona huh
# < donald glover is .
#
# > non-american i'd
# = as a non-american , i'd have to say this song and video do a really , really good job of getting across just how bizarre and borderline insane the us seems to an outside observer .
# < i'm here after i the
#
# 17m 21s (- 13m 16s) (42500 56%) 3.8226
# > wish america
# = i wish america loved black people as much as they love black culture - jalen rose
# < i love america <EOS>
#
# > troy abed
# = troy and abed in america !
# < i dont black lives matter . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 17m 34s (- 13m 5s) (43000 57%) 4.0424
# > malaysia
# = this is malaysia
# < this is america <EOS>
#
# > still absolute
# = this is still an absolute masterpiece
# < this is still still america <EOS>
#
# 17m 47s (- 12m 53s) (43500 57%) 3.9170
# > america continet
# = america is a continet ! ! ! person_tipping_hand male_sign_selector
# < america is america <EOS>
#
# > really loved
# = i was really loved by your review . this song/video really moves me .
# < we really really really like the song . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 17m 59s (- 12m 40s) (44000 58%) 3.8126
# > remember song
# = remember when this song was actually relavant loudly_crying_face
# < i just song this song song <EOS>
#
# > else come
# = who else come from " this is america , so call me maybe " ? *
# < who else is here after the this  the this  the  <EOS>
#
# 18m 12s (- 12m 28s) (44500 59%) 3.8763
# > still greatest
# = still the greatest country on earth flexed_biceps regional_indicator_symbol_letter_u regional_indicator_symbol_letter_s amazing song though . way to make hip-hop great again childish gambino !
# < this is still still relevant . . . . . . . . . . . . <EOS>
#
# > never listened
# = i never listened to this song when it first came out . listening to this actually is a good representation of america . i swear as soon as i turn 18 im moving to canada
# < the is this is is . <EOS>
#
# 18m 24s (- 12m 16s) (45000 60%) 3.7909
# > rip george
# = rip george floyd purple_heart
# < rip george floyd was a the
#
# > who's listening
# = who's listening this in 2020
# < who's here after in the song <EOS>
#
# 18m 36s (- 12m 4s) (45500 60%) 3.6771
# > people disliked
# = the people who disliked this are racist and trump supporters       periodt
# < the people who disliked this song are racist <EOS>
#
# > who's fourth
# = who's here on fourth of july in 2020 ? fireworks
# < who's here after george floyd and this is  <EOS>
#
# 18m 49s (- 11m 51s) (46000 61%) 3.8593
# > man predicted
# = my man predicted the future red_heart_selector
# < this man predicted the future . <EOS>
#
# > rip george
# = rip george floyd raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
# < george george floyd was a .
#
# 19m 1s (- 11m 39s) (46500 62%) 3.7014
# > america continent
# = but . . . america it's a continent , no a contry ^
# < america is a continent continent a country <EOS>
#
# > everyone im
# = everyone im not even surprised anymore .             me hes so hot at 0 36 smiling_face_with_heart-eyes smiling_face_with_heart-eyes
# < im im im to
#
# 19m 13s (- 11m 27s) (47000 62%) 3.6922
# > troy got
# = troy got deep after his journey around the world
# < i got the to this . <EOS>
#
# > muslim said
# = some muslim said this song is about muslims whens its about racism
# < the this is the <EOS>
#
# 19m 26s (- 11m 15s) (47500 63%) 3.6894
# > america 3rd
# = america is just a 3rd world country with a gucci belt on
# < america is a continent continent
#
# > another rich
# = another rich dickhead telling lies about the country that's made him rich
# < 1 55 is this <EOS>
#
# 19m 38s (- 11m 3s) (48000 64%) 3.6047
# > one dislike
# = am i the only one who dislike this shit ?
# < the only one who one of the this <EOS>
#
# > blacks lives
# = blacks lives matter ! ! !
# < black lives matter raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist
#
# 19m 50s (- 10m 50s) (48500 64%) 3.6868
# > like character
# = he is like a character who can only be unlocked by americans .
# < i like like this like <EOS>
#
# > wtf killing
# = wtf you are killing people
# < the dislikes are .  . .  .  <EOS>
#
# 20m 2s (- 10m 38s) (49000 65%) 3.5353
# > rage machine
# = this and rage against the machine are the protest music for 2020
# < whos here after this song ? <EOS>
#
# > stupidest song
# = this is the stupidest song , subliminal brain washing at its finest .
# < i hate this song song <EOS>
#
# 20m 15s (- 10m 26s) (49500 66%) 3.7098
# > white lives
# = white lives matters too
# < black lives matter raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist
#
# > might audio
# = this might be both audio and visual , one of the worst thing ever made . squinting_face_with_tongue squinting_face_with_tongue squinting_face_with_tongue
# < this is a <EOS>
#
# 20m 27s (- 10m 13s) (50000 66%) 3.6041
# > made jorge
# = this was made before jorge floyd died to
# < this was made made to be a message . . . . . . . . . . . . . . . . . . . . . .
#
# > yeah america
# = yeah america isnt the best , but havent you seen the racism in africa against white people ? havent you seen the rest of the world ? ?
# < this is america america america <EOS>
#
# 20m 39s (- 10m 1s) (50500 67%) 3.6320
# > oofing america
# = this is a oofing america right
# < this is is america america . <EOS>
#
# > black white
# = this is about black and white fight and going on in the world we in media not doing anything like that when he say im so pretty look in the back we need to stop doing that
# < black live in this is america <EOS>
#
# 20m 51s (- 9m 48s) (51000 68%) 3.5230
# > one notices
# = so no one notices the protests and riots in the background or these young men with these covid masks on . " this is celly , that's a tool " . . .
# < no one one only one one only one who is america <EOS>
#
# > shit america
# = shit america brought me here
# < this is america america
#
# 21m 4s (- 9m 36s) (51500 68%) 3.5882
# > might seem
# = this might seem like a joke but he tryin to convey a message even though he a comedian
# < i a to the <EOS>
#
# > hot
# = this is not hot
# < i'm <EOS>
#
# 21m 16s (- 9m 24s) (52000 69%) 3.6137
# > people keep
# = why do people keep saying he predicted the future this has been going on for hundreds of years . y'all are now just taking notice . it's about time ! #blm
# < people are the people are the people that america is <EOS>
#
# > remember came
# = remember when this came out and everyone was shook and now its just normal lmao
# < i i knew came out 2 years ago <EOS>
#
# 21m 28s (- 9m 12s) (52500 70%) 3.6710
# > many people
# = many people came after cops choked a man to death , and thats just sad
# < people who disliked are are of people who are .  <EOS>
#
# > song rasist
# = t the song rasist cause he kill all black
# < this song is so relevant right now <EOS>
#
# 21m 41s (- 9m 0s) (53000 70%) 3.8131
# > donald letting
# = donald just letting us know hes talented at every single thing hes ever done
# < donald glover is a . <EOS>
#
# > funny song
# = funny how this song really represents whats happening now
# < this a song song song .  <EOS>
#
# 21m 54s (- 8m 48s) (53500 71%) 3.8170
# > black people
# = black people they are human beings there are men who are beautiful , very smart , and pretty black girls , racism is the stupidest thing in life .
# < the people people that disliked are the people that america  <EOS>
#
# > joe biden
# = joe biden is the president now . . .
# < this is a <EOS>
#
# 22m 6s (- 8m 35s) (54000 72%) 3.7066
# > im sorry
# = im sorry to say his while living in america but fuck our flag the flag is supposed to symbolize freedom and i dont see no freedom around here
# < im sorry but this is america
#
# > black man
# = black man get your money " what's the message behind it ?
# < i dont say this this is <EOS>
#
# 22m 18s (- 8m 23s) (54500 72%) 3.6644
# > others countries
# = how others countries sees america
# < 1 55 the raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone  <EOS>
#
# > i'm white
# = i'm white so you say i can't understand but you also say my silence is violence . you just want to hate me and i will not allow it .
# < i'm in the the and the .  <EOS>
#
# 22m 30s (- 8m 11s) (55000 73%) 3.6675
# > girl took
# = that girl who took photos pretending to board up that store at the protests didn't even realize this song is about her
# < rest in peace george floyd . . . . .
#
# > understand black
# = i don't understand why black people hispanics and others are treated differently than white people . we all are humans . made by the same god . there is no difference
# < i am are to this the <EOS>
#
# 22m 42s (- 7m 58s) (55500 74%) 3.6150
# > killing real
# = are you killing real ppl thinking_face thinking_face
# < this is the the <EOS>
#
# > everybady say
# = why are everybady say r . i . p george floyd ?
# < i dont are are are this is  <EOS>
#
# 22m 55s (- 7m 46s) (56000 74%) 3.6475
# > whos seeing
# = whos here after seeing all the police brutality and this pandemic tired_face ?
# < whos here after this song the .
#
# > literally america
# = this is literally america rn in august 2020
# < this is is america . .
#
# 23m 8s (- 7m 34s) (56500 75%) 3.5417
# > wow watching
# = wow i am watching peoples reactions to this song and the more and more i do the more and more i notice that they dont see what is really happening in the background person_facepalming medium_skin_tone female_sign_selector
# < wow watching this in 2020 . <EOS>
#
# > america
# = this is america ?       no !       this is pile_of_poo pile_of_poo backhand_index_pointing_left
# < this is america
#
# 23m 20s (- 7m 22s) (57000 76%) 3.4770
# > song cool
# = the song is cool but the video also fuck you
# < this song is so well more and more accurate . <EOS>
#
# > looking song
# = looking at this song now . nothing changed and it sucks to see no matter how many riots we do . police continue to harm and dont do a political change
# < i remember of this song song .   <EOS>
#
# 23m 31s (- 7m 9s) (57500 76%) 3.5003
# > somebody posted
# = somebody posted about george floyd . and that is not at all related to this .
# < i is it is <EOS>
#
# > america almost
# = this is america , almost civil war but we still in love with america
# < america is a a continent of a <EOS>
#
# 23m 44s (- 6m 57s) (58000 77%) 3.4052
# > beautiful song
# = beautiful song with a beautiful message . but def would not bump this in a car if i'm tryna catch a vibe with shawty . especially on the 1st date lmao just my opinion
# < this this song is song <EOS>
#
# > justice george
# = justice for george floyd raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone       it doesnt matter if black or white red_heart
# < george floyd was  <EOS>
#
# 23m 56s (- 6m 45s) (58500 78%) 3.5623
# > song really
# = this song really is hitting different after all that's going on . 2020 is a great year .
# < this song really really like this song <EOS>
#
# > america black
# = this is america , where a black man can make millions by saying he's oppressed . god bless america .
# < this is america america  <EOS>
#
# 24m 9s (- 6m 33s) (59000 78%) 3.6377
# > idiots mental
# = idiots this is about his mental health lmao
# < why did they shoot them <EOS>
#
# > fun fact
# = fun fact this song is legendary .
# < fun fact that this is in
#
# 24m 21s (- 6m 20s) (59500 79%) 3.5232
# > imagine defending
# = imagine defending a career criminal that held a gun to a pregnant womans belly , black lives matter is a joke
# < imagine you all the kids are wearing masks <EOS>
#
# > imagined quiet
# = imagined being an quiet kid sings " this is america " but u lived in the wrong country/continent skull
# < the , that this
#
# 24m 33s (- 6m 8s) (60000 80%) 3.5291
# > young 12
# = my young 12 year old self final noticed what this song means after years of listening to it . . . . * sighs * pensive_face
# < the all of the . <EOS>
#
# > god gives
# = god gives all girls boobs       me can i have some ?       god no but he can
# < when you shot the real the you shot
#
# 24m 45s (- 5m 56s) (60500 80%) 3.3676
# > guy literally
# = this guy literally predicted 2020
# < this guy literally predicted the future . <EOS>
#
# > made 2018
# = this was made in 2018 , but , this explains what politics is like in 2020 .
# < this was made 2018 in 2020 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 24m 57s (- 5m 43s) (61000 81%) 3.5139
# > ahorita conecto
# = ahorita me conecto a blow stars
# < this is not in  <EOS>
#
# > future billionaires
# = only future billionaires like this
# < r . i . p george floyd . <EOS>
#
# 25m 9s (- 5m 31s) (61500 82%) 3.4489
# > tiktok
# = tiktok ! ?
# < this is the
#
# > lets take
# = lets all take a moment to imagine if this song came out now in 2020 .
# < lets be be be a song <EOS>
#
# 25m 22s (- 5m 19s) (62000 82%) 3.4660
# > song never
# = this y this song will never get old cuz it keeps happening again and again       a few days ago i guy got shot 7 times on his back infront of his own kids
# < this song is so more and more accurate <EOS>
#
# > oh god
# = oh god , this man looks like lando calrissian from star wars
# < oh a god <EOS>
#
# 25m 35s (- 5m 7s) (62500 83%) 3.4452
# > predicted 2020
# = they predicted 2020 ! lol
# < he predicted 2020 2020 <EOS>
#
# > dislikes white
# = the dislikes are just white cops mad asl
# < this is the the  <EOS>
#
# 25m 47s (- 4m 54s) (63000 84%) 3.3648
# > horrible fucking
# = horrible fucking song , typical liberal bullshit
# < amrica is a . <EOS>
#
# > hot
# = this is not hot
# < this is
#
# 26m 0s (- 4m 42s) (63500 84%) 3.4948
# > raised_fist dark_skin_tone
# = raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist medium_skin_tone raised_fist medium_light_skin_tone raised_fist light_skin_tone
# < raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist raised_fist  <EOS>
#
# > song gives
# = this song gives me shivers now , because of whats happening in america
# < this song is me in 2020 in the  <EOS>
#
# 26m 12s (- 4m 30s) (64000 85%) 3.5311
# > song demonic
# = this song is demonic , the youth of america are posed .
# < this song is a . <EOS>
#
# > okay americans
# = okay . americans , so this is america ?
# < i am gonna be the only one is a <EOS>
#
# 26m 24s (- 4m 17s) (64500 86%) 3.5186
# > persone died
# = why the persone that died came back to life .
# < the the the the and the <EOS>
#
# > america far-left
# = this will be america when the far-left democrats defund the police . flushed_face " no thanks " ! face_with_steam_from_nose
# < america is a continent a country america is a continent <EOS>
#
# 26m 37s (- 4m 5s) (65000 86%) 3.5942
# > try earning
# = try earning respect . i stead of demanding it , with nothing to back it up
# < we are the and this video are the and the video are the and this song is still america . <EOS>
#
# > perfect song
# = this is the perfect song for 2020 police be trippin now this is america !
# < this is this song song song song song <EOS>
#
# 26m 49s (- 3m 53s) (65500 87%) 3.4870
# > yeah song
# = yeah the song really sucks yeah
# < this is the song song <EOS>
#
# > idk rap
# = idk how rap became popular
# < this is the the the the , this <EOS>
#
# 27m 2s (- 3m 41s) (66000 88%) 3.4135
# > kill real
# = you kill him for real ? ? ? ? ? /
# < did he kill them for me . <EOS>
#
# > 10m likes
# = why does this have 10m likes
# < why does he have kill someone guy from community ! <EOS>
#
# 27m 14s (- 3m 28s) (66500 88%) 3.4653
# > saying black
# = saying black man over and over isnt deep
# < he saying " he he was he
#
# > real american
# = how real is the american dream ?
# < american american american american american , but the american dislikes are from community ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
#
# 27m 26s (- 3m 16s) (67000 89%) 3.4837
# > f dude
# = f this dude and his spastics
# < f you guys that the kids the the the <EOS>
#
# > 2 27
# = 2 27 gambino wanted to tell us about the coronavirus before it hits , people recording with their face covered
# < 2 27 the the wearing masks <EOS>
#
# 27m 39s (- 3m 4s) (67500 90%) 3.5640
# > national anthem
# = the national anthem of the apocalypse !
# < this is the this this this this this this this  . <EOS>
#
# > america continent
# = america is a continent not a country including latin america and north america
# < america is a continent not not a country , not , not , and racism . . . . .
#
# 27m 51s (- 2m 52s) (68000 90%) 3.3627
# > gzel ark
# = gzel ark raised_back_of_hand dark_skin_tone hand_with_fingers_splayed light_skin_tone vulcan_salute medium_skin_tone
# < this is a a a the ? <EOS>
#
# > think protests
# = i think the protests are being too much but i like this song
# < i think think about the  <EOS>
#
# 28m 4s (- 2m 39s) (68500 91%) 3.4051
# > fun fact
# = fun fact this song is based off the horror movie known as * america *
# < fun fact that this is in fact that america is <EOS>
#
# > 717 000
# = 717 , 000 people disliked this because the truth makes them fucking uncomfortable .
# < we we gonna talk about the future <EOS>
#
# 28m 17s (- 2m 27s) (69000 92%) 3.5211
# > anyone realize
# = anyone realize this foreshadowed the shit outta whats happening rn . down to the horse riding by . i know yall seeing this shit
# < anyone who else are from the the . <EOS>
#
# > expecting already
# = i was expecting this already
# < i just gonna to this , but i just really shoot that guy
#
# 28m 30s (- 2m 15s) (69500 92%) 3.4695
# > nada
# = nada             absolutamente nada             tic tok this is american
# < this is is <EOS>
#
# > latinoamerica
# = this is latinoamerica
# < this is is <EOS>
#
# 28m 43s (- 2m 3s) (70000 93%) 3.5606
# > black lives
# = black lives matter raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone
# < black lives matter raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone  <EOS>
#
# > shoot back
# = why shoot back man go to jail !
# < who thought here from flying <EOS>
#
# 28m 55s (- 1m 50s) (70500 94%) 3.4059
# > car park
# = if this is a car park , why are there no cars *
# < this is a masterpiece
#
# > yea anything
# = yea . if anything represents americana . . . . its this . #carryeem
# < i am i this <EOS>
#
# 29m 8s (- 1m 38s) (71000 94%) 3.5355
# > 1 02
# = 1 02       a meme was born
# < 1 55
#
# > hits differently
# = this hits differently today
# < this hits different in . <EOS>
#
# 29m 19s (- 1m 26s) (71500 95%) 3.3522
# > country proud
# = this is my country ! i am proud to be an american ! god bless our country ! lets go biden ! ! !
# < this is a country ! <EOS>
#
# > 2019 america
# = 2019 this is america             2020 this is cororica
# < this is is america . . . . . <EOS>
#
# 29m 32s (- 1m 13s) (72000 96%) 3.4427
# > one thinks
# = am i the only one who thinks this dude looks like that guy from community ?
# < no one one of the . <EOS>
#
# > wearing medical
# = they wearing medical masks before corona huh
# < the only people that america <EOS>
#
# 29m 45s (- 1m 1s) (72500 96%) 3.4466
# > predicted riot
# = predicted riot ?
# < he predicted the future <EOS>
#
# > matter american
# = it doesn't matter if you're american or european , this song still represents what's happening everywhere and i think he's done a good job showcasing it .
# < i am not american american in a
#
# 29m 58s (- 0m 49s) (73000 97%) 3.3829
# > song still
# = song still sucks even in 2020
# < this song is still relevant than it america <EOS>
#
# > yeah america
# = yeah america isnt the best , but havent you seen the racism in africa against white people ? havent you seen the rest of the world ? ?
# < this is is america america ! ! <EOS>
#
# 30m 9s (- 0m 36s) (73500 98%) 3.3649
# > police trippin'
# = police be trippin' " for sure . but his face kinda is too .
# < police be trippin' now
#
# > video masterpiece
# = this video is a masterpiece concept , talent , art , reality , brutality . you won't be left unhurt after watching it .
# < this video is a . in .  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 30m 22s (- 0m 24s) (74000 98%) 3.3266
# > officially anthem
# = this is officially the anthem of the protests .
# < this is is the song <EOS>
#
# > said cant
# = he said " i cant breathe " but the police dont care because " this is america " #blacklivesmatter
# < imagine said i cant breathe "
#
# 30m 34s (- 0m 12s) (74500 99%) 3.4177
# > raised_fist dark_skin_tone
# = raised_fist dark_skin_tone raised_fist dark_skin_tone raised_fist dark_skin_tone regional_indicator_symbol_letter_t regional_indicator_symbol_letter_h
# < raised_fist raised_fist dark_skin_tone raised_fist dark_skin_tone raised_fist dark_skin_tone raised_fist dark_skin_tone raised_fist medium_dark_skin_tone raised_fist  <EOS>
#
# > u know
# = now u know the guy shot stood up and fell on the floor
# < u know this this 2 years later and this song is the . <EOS>
#
# 30m 46s (- 0m 0s) (75000 100%) 3.3486
# > who's george's
# = who's here after george's die
# < who's here on the election <EOS>
#
# > music video
# = this music video is so childish .
# < this music video is so powerful <EOS>

# %%
hidden_size = 300
best_encoder = EncoderRNN(input_sentence.n_words, hidden_size).to(device)
best_decoder =  AttnDecoderRNN(hidden_size, output_sentence.n_words, dropout_p=0.1).to(device)
# best_decoder =  DecoderRNN(hidden_size, output_sentence.n_words).to(device)
best_encoder.load_state_dict(torch.load(path_to_final_project + checkpoint_folder_path + encoder_checkpoint_name, map_location=torch.device('cpu')))
best_decoder.load_state_dict(torch.load(path_to_final_project + checkpoint_folder_path + decoder_checkpoint_name, map_location=torch.device('cpu')))
best_encoder.eval()
best_decoder.eval()
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(9991, 300)
#   (attn): Linear(in_features=600, out_features=40, bias=True)
#   (attn_combine): Linear(in_features=600, out_features=300, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lstm): LSTM(300, 300)
#   (out): Linear(in_features=300, out_features=5418, bias=True)
# )

# %%
#evaluate based on training set
evaluateRandomly(best_encoder, best_decoder,pairs,n=100)
# Out:
# > truely masterpiece
# = this is truely a masterpiece . we analysed this music video today in english class and oh boy it is insane how many messages and references are hidden in the song and the video . . .
# < i you dont get the song <EOS>
#
# > question rlly
# = my question did he rlly kill ppl for this vid
# < this is a is
#
# > america music
# = this is america most of the music is copyrighted so we cant use them thank you .
# < this is america is <EOS>
#
# > america built
# = america is built on some innocent peoples graves
# < this is america ,
#
# > teacher slaves
# = teacher not all of them were slaves there was people that was black but they have money me okay
# < my the gun is <EOS>
#
# > directed abed
# = directed by abed nadir       brought to you by cool abed films
# < this is a <EOS>
#
# > anyone else
# = anyone else notice when the camera pans over the guys upstairs on the railing every one of them is wearing a mask . pre covid .
# < anyone else else the kids wearing masks ? <EOS>
#
# > yes fucking
# = yes it fucking is and im sick of it .
# < this is a is   <EOS>
#
# > predicted 2020
# = he just predicted 2020
# < he predicted 2020 . .
#
# > isnt crazy
# = isnt crazy when this song was put out everything was wasnt as bad now these things are normal sad .
# < this is literally to be the song is <EOS>
#
# > hope one
# = hope one day this song wont be accurate anymore .
# < i we believe this is
#
# > know tha
# = how did he know tha this was going to happend
# < i know know know this song is <EOS>
#
# > america
# = this is america             black lives matter victory_hand medium_skin_tone
# < this is america
#
# > comment
# = this is a comment
# < this is a <EOS>
#
# > crazy theres
# = crazy how theres rioting and looting in europe now . this isnt just america now #rcab
# < the dislikes are from the song <EOS>
#
# > one thing
# = one thing bad timing when the guy fell when he shot him in the hand
# < am i the only one who the song is
#
# > also want
# = i also want to listen this is china .
# < i dont live in the <EOS>
#
# > pray george
# = pray for george floyd palms_up_together palms_up_together palms_up_together
# < george floyd was a <EOS>
#
# > 700k dislikes
# = 700k dislikes ? ? ? this gives a msg who tf dislike this
# < the dislikes are from the people that the people that is <EOS>
#
# > wer pepole
# = wer pepole achely killd in dis music video
# < this is this <EOS>
#
# > north america
# = that is north america . " america " is bigger than that .
# < this is is america is <EOS>
#
# > song keeps
# = this song keeps getting more realistic .
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > say fuck
# = say it with me fuck the police .
# < the dislikes are from the song is   <EOS>
#
# > song dumb
# = the song is dumb but the dancing is great
# < this song is so more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > song played
# = this song should be played in the protests now .
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > 700 thousand
# = more than 700 thousand people did not like to see a black man win again
# < the dislikes are from the <EOS>
#
# > who's watching
# = who's watching this in june 30 2020
# < who's watching watching this is america .
#
# > 1 sign_of_the_horns
# = 1 sign_of_the_horns raising_hands
# < 1 55 is
#
# > trump worst
# = trump is your worst choice america
# < this is is is song is   <EOS>
#
# > true
# = is the true . .
# < this is is <EOS>
#
# > america right
# = this is america , right now .
# < this is america , this is america <EOS>
#
# > saddest part
# = the saddest part about this is everything he's saying is true
# < the dislikes are from the people that the people that is <EOS>
#
# > powerful line
# = most powerful line get your money black men
# < i you dont get the song <EOS>
#
# > song means
# = this song means alot in the time being at the moment .
# < this song song song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > know gray
# = you do know those gray colored civil war pants belonged to the confederates aka democratic party that wanted to keep their slaves right ? educate yourself bruh . stop blaming the republicans for the democratic partys mistakes !
# < i know know know know this song is   <EOS>
#
# > stupid keep
# = this is stupid keep on adding gas on the fire see what happens
# < this is a is  <EOS>
#
# > hate kids
# = i hate kids i am a wife beater and beat my kid everydy till he bleeds until his skin comes pff
# < i dont live in the people that is america <EOS>
#
# > else comments
# = who else is at the comments section
# < who else is here after george floyd
#
# > troyyyy @best
# = troyyyy @best
# < i you dont get the song <EOS>
#
# > dislikes racist
# = the dislikes are from racist people .
# < the dislikes are from the <EOS>
#
# > piece shit
# = this is a piece of shit .
# < this is a <EOS>
#
# > americans meh
# = americans before meh       americans now * this song makes so much sense now *
# < the dislikes are from the <EOS>
#
# > who's flying
# = who's here from flying kitty
# < who's here after george floyd
#
# > song love
# = is its only me or after this song you love america even more than before ?
# < this song hits different in 2020 . . .
#
# > say song
# = they say that this song is about racism , bruh read the lyrics , its vague af
# < i the song song song is   <EOS>
#
# > community leave
# = community leave in the chat )
# < we the only the is
#
# > shyca ist
# = shyca ist grad cabana
# < i you know this song is   <EOS>
#
# > listen america
# = listen america , donald glover here has already laid all your problems out for you so why the heck arent you changing . its been 2 years
# < this is is america is <EOS>
#
# > man teens
# = man these teens ba talented
# < man man predicted the future <EOS>
#
# > u burst
# = if u don't burst into tears during the seventeen seconds of silence . . . . . i don't know what to tell you
# < i dont live in the people that is <EOS>
#
# > us europeans
# = us europeans look at america like this , and laugh at their people .
# < he was a to <EOS>
#
# > america right
# = this is america right now       proper purge       so sad to see the country fall because of a rubbish leader
# < this is america , this is america <EOS>
#
# > stupid video
# = this is a stupid video
# < this video is video video
#
# > 2018 american
# = 2018 this is american             2020 holy shit ! this is america ?
# < this is
#
# > yeah america
# = yeah , this is america pensive_face
# < this is is america .
#
# > one important
# = one of the most important rap songs ever recorded . . fucking pigs
# < am i the only one who the this is
#
# > someone explain
# = can someone explain to me why he kills a guy with a tokarev and then kills a choir with an ak su ?
# < this is a to <EOS>
#
# > george floyds
# = george floyds murder has nothing to do with race as theres no proof it was . . .
# < george floyd was a <EOS>
#
# > song look
# = doesn't this song look real now ? ( rip george flyod )
# < this song is song more relevant now <EOS>
#
# > song played
# = this song should be played in the protest on the street .
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > song cool
# = the song is cool but the video also fuck you
# < this song is song more relevant now <EOS>
#
# > fuck song
# = fuck this song
# < the song song song song song is   <EOS>
#
# > donald glover
# = donald glover is bisexual and promotes feminization on the black community
# < donald glover is a the the  <EOS>
#
# > know america
# = do you know " america " is the continent , your country is the united states , in " america " there is a lot of countries , like brazil , argentina , and others
# < we we really is america .
#
# > george floyd
# = george floyd was a thug . . . . . no one special . . . . the radical left is using him as excuse to stir anarchy , racial division and destroy trump . . . .
# < george floyd was a <EOS>
#
# > 2 35
# = in 2 35 you can see jair bolsonaro enjoying his horse
# < 2 29
#
# > warned us
# = he warned us it was going to get worst
# < he was a <EOS>
#
# > saw video
# = i saw a video in my recommendation saying " this song is racism towards black people " , dude are you blind he is latterly black
# < what the video is a song , but i dont get it . <EOS>
#
# > white people
# = white people are mad that black people got rights now so they do hurtful stuff to them
# < the people people people that people that people that is america <EOS>
#
# > america
# = this is america       guns in my area
# < this is america
#
# > love black
# = we love black people . we have not any racism .       love from turkey
# < i love how this is america . <EOS>
#
# > hell shoot
# = why the hell did he shoot that guy who was holding the guitar
# < i did he he guy guy
#
# > waawww
# = waawww . . .             heart_suit
# < this is <EOS>
#
# > 2 years
# = 2 years ago and things have gotten worse . . . in excess
# < 2 years later and its still america . . .
#
# > raised_fist dark_skin_tone
# = raised_fist dark_skin_tone this is america . . .
# < raised_fist raised_fist light_skin_tone raised_fist medium_light_skin_tone raised_fist medium_skin_tone raised_fist medium_dark_skin_tone raised_fist dark_skin_tone  <EOS>
#
# > try earning
# = try earning respect . i stead of demanding it , with nothing to back it up
# < the dislikes are from the <EOS>
#
# > jacob blake
# = jacob blake . tamir rice . eric garner . michael brown . breonna taylor . trayvon martin . george floyd . elijah mcclain . emmett till . 9 out of thousands . how many more ?
# < who is here after george floyd
#
# > pisses ppl
# = pisses me off that ppl really be this nasty about race
# < who is here after the george floyd <EOS>
#
# > dont get
# = i dont get the point in dis song
# < i dont get the song <EOS>
#
# > who's stupid
# = who's stupid enough to ask " what does this song mean ? "
# < who's here after the song <EOS>
#
# > someone wear
# = someone * * doesn't wear a mask * *       what everyone wants to do 0 48
# < the dislikes are from the <EOS>
#
# > swear want
# = i swear i want someone to blast this music when they protesting
# < i dont live in the people that is <EOS>
#
# > wait donald
# = wait so donald glover knew the future ? cause today people are going crazy .
# < donald glover is the only one who the <EOS>
#
# > get updated
# = can we get an updated video of 'rona in america ?
# < i don't get the song is <EOS>
#
# > song hits
# = this song now hits reality . ive already lost hope for america .
# < this song hits different in 2020 . . .
#
# > fact 2
# = the fact that this is 2 years ago it feels like 4 months since it came out face_with_open_mouth
# < the fact that he came here after george floyd .
#
# > came back
# = who came back to watch this after jacob blake person_facepalming medium_skin_tone male_sign_selector
# < we came out 2 years later and its still america . . . .
#
# > song trash
# = this song is trash bro don't see what the hype is about
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > 2 years
# = 2 years later , if you'ar watching this you'ar a legend
# < 2 years later and its still america . . .
#
# > hits different
# = it hits different in 2020 coz of gorge floyds death because of his race
# < this hits different in 2020 . . .
#
# > whos riots
# = whos here during the riots around the country because of george floyds death
# < whos here after george floyd
#
# > 2 years
# = 2 years later                               this is still america
# < 2 years later and its still america . . .
#
# > watching 2020
# = if you're watching this in 2020 , you're a legend
# < this is watching 2020 2020
#
# > reason came
# = the reason why i came here is because of racism and the deaf of george floyd .
# < i just came here after the george floyd was a <EOS>
#
# > america biden
# = this is america ! biden 2020
# < this is america is <EOS>
#
# > 2020 america
# = 2020 . this is america
# < this is is america .
#
# > donald need
# = the only donald we need in this country
# < donald glover is this <EOS>
#
# > song black
# = it this a song for black lifes matter ?
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > definitely need
# = we definitely need a this is america part 2 in 2020 . . .
# < i am i the only one who the this
#
# > police trippin'
# = police be trippin' now "             this did not age well
# < i dont live in this is america . <EOS>

# %%
#evaluate based on test set
evaluateRandomly(best_encoder, best_decoder,test_pairs,n=100)
# print(test_pairs)
# Out:
# > song hes
# = no reply
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > realize song
# = no reply
# < what song this song is song <EOS>
#
# > hard believe
# = no reply
# < i i know know this song is <EOS>
#
# > wait minute
# = no reply
# < wait here after the kids wearing masks masks ? <EOS>
#
# > movie music
# = no reply
# < this is this song is song <EOS>
#
# > damn cant
# = no reply
# < i i cant believe this is song
#
# > crazy
# = no reply
# < this is <EOS>
#
# > there's reason
# = no reply
# < i you are the to <EOS>
#
# > comment
# = no reply
# < this is a <EOS>
#
# > two movements
# = no reply
# < the dislikes are from the song <EOS>
#
# > song perfect
# = no reply
# < this song is song song song is   <EOS>
#
# > else watched
# = no reply
# < who else is here after george floyd
#
# > people saying
# = no reply
# < people are people people that people that is america
#
# > thank message
# = no reply
# < is this is <EOS>
#
# > must taken
# = no reply
# < this is a <EOS>
#
# > people 2021
# = no reply
# < people are people disliked this song is <EOS>
#
# > love watch
# = no reply
# < i love it <EOS>
#
# > 2018 youtube
# = no reply
# < this is is is
#
# > that's call
# = no reply
# < this is is song is  <EOS>
#
# > 2020 ;
# = no reply
# < 2020 . .
#
# > one comes
# = no reply
# < am i the only one who the this
#
# > check video
# = no reply
# < this is this video video
#
# > can't believe
# = no reply
# < i can't believe this is song is   <EOS>
#
# > see dancing
# = no reply
# < the dislikes are from the <EOS>
#
# > expecting call
# = no reply
# < this is is song is   <EOS>
#
# > remembers came
# = no reply
# < the only the who is
#
# > got plug
# = no reply
# < i got shot the kids wearing masks <EOS>
#
# > crazy
# = no reply
# < this is <EOS>
#
# > expecting call
# = no reply
# < this is is song is   <EOS>
#
# > love everyone
# = no reply
# < i love how this is america . <EOS>
#
# > nigga aaron
# = no reply
# < this is a to <EOS>
#
# > hey guy
# = no reply
# < this is is guy
#
# > song makes
# = no reply
# < this song is so more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > amrica dream
# = no reply
# < this is a is  <EOS>
#
# > dislikes police
# = no reply
# < the dislikes are from the <EOS>
#
# > thought europe
# = no reply
# < i did he he shot the people that is <EOS>
#
# > someone please
# = no reply
# < i dont like this song <EOS>
#
# > hello 8
# = no reply
# < the dislikes are from the <EOS>
#
# > ain't heard
# = no reply
# < the dislikes are from the people that is <EOS>
#
# > future
# = no reply
# < this is <EOS>
#
# > dancing finest
# = no reply
# < i the to the <EOS>
#
# > anyone else
# = no reply
# < anyone else else the kids wearing masks ? <EOS>
#
# > america
# = no reply
# < this is america
#
# > days days
# = no reply
# < this is is <EOS>
#
# > cool america
# = no reply
# < this is america
#
# > dancing finest
# = no reply
# < i the to the <EOS>
#
# > good message
# = no reply
# < the dislikes are from the <EOS>
#
# > bet guys
# = no reply
# < we you are the same . <EOS>
#
# > came america
# = no reply
# < we came out 2 years later and its still america . . . .
#
# > never noticed
# = no reply
# < i dont know the song is <EOS>
#
# > guys wearing
# = no reply
# < he he wearing masks wearing masks <EOS>
#
# > interesting song
# = no reply
# < the song song song song is   <EOS>
#
# > beginning like
# = no reply
# < i like this is like this song <EOS>
#
# > memes video
# = no reply
# < this is this video
#
# > song aged
# = no reply
# < this song is song more relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as relevant as a message . <EOS>
#
# > check video
# = no reply
# < this is this video video
#
# > shit genius
# = no reply
# < this is a song <EOS>
#
# > racist virus
# = no reply
# < this is here to be the  <EOS>
#
# > serious likes
# = no reply
# < the dislikes are from the people that is <EOS>
#
# > patrick
# = no reply
# < 1
#
# > donald glover
# = no reply
# < donald glover is a the the  <EOS>
#
# > subscribe pls
# = no reply
# < the dislikes are from the <EOS>
#
# > america right
# = no reply
# < this is america , this is america <EOS>
#
# > video like
# = no reply
# < this is this america is <EOS>
#
# > serious likes
# = no reply
# < the dislikes are from the people that is <EOS>
#
# > love watch
# = no reply
# < i love it <EOS>
#
# > much dislike
# = no reply
# < i the only the who who is song this song <EOS>
#
# > know didnt
# = no reply
# < i know know know this song is  <EOS>
#
# > video like
# = no reply
# < this is this america is <EOS>
#
# > dude thought
# = no reply
# < this was a that the song is <EOS>
#
# > gonna find
# = no reply
# < i just gonna talk about the kids wearing masks . <EOS>
#
# > watching flyingkitty
# = no reply
# < i watching watching to this song is <EOS>
#
# > miss ft
# = no reply
# < this is a is <EOS>
#
# > time goes
# = no reply
# < i dont live in the <EOS>
#
# > represent like
# = no reply
# < i like this is like this song <EOS>
#
# > america gotta
# = no reply
# < this is america ,
#
# > didnt predict
# = no reply
# < i you like this song is <EOS>
#
# > ain't heard
# = no reply
# < the dislikes are from the people that is <EOS>
#
# > feel like
# = no reply
# < i feel like this song is <EOS>
#
# > use 1b
# = no reply
# < this is a to <EOS>
#
# > beginning like
# = no reply
# < i like this is like this song <EOS>
#
# > iran wants
# = no reply
# < this is a to <EOS>
#
# > describes us
# = no reply
# < we just predicted the future <EOS>
#
# > imagine canada
# = no reply
# < he he knew the only the song <EOS>
#
# > america third
# = no reply
# < this is america ,
#
# > realize video
# = no reply
# < this is this video
#
# > damn cant
# = no reply
# < i i cant believe this is song
#
# > fuck u
# = no reply
# < the dislikes are from the <EOS>
#
# > like america
# = no reply
# < i like this is america is <EOS>
#
# > africa
# = no reply
# < this is is <EOS>
#
# > use 1b
# = no reply
# < this is a to <EOS>
#
# > america kill
# = no reply
# < this is america ,
#
# > real music
# = no reply
# < this is this song song is song <EOS>
#
# > bet guys
# = no reply
# < we you are the same . <EOS>
#
# > must taken
# = no reply
# < this is a <EOS>
#
# > subscribe pls
# = no reply
# < the dislikes are from the <EOS>
#
# > 2020 still
# = no reply
# < am i the only one who song this song is <EOS>
#
# > dont understand
# = no reply
# < i dont dont . <EOS>
#
# > current state
# = no reply
# < this is is is is  <EOS>
#
# > going talk
# = no reply
# < i dont like this is <EOS>

# %%
#Run below two lines (in google colab), installation steps to get .pdf of the notebook

# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pandoc is already the newest version (1.19.2.4~dfsg-1build4).
# pandoc set to manually installed.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
# Suggested packages:
#   fonts-noto apache2 | lighttpd | httpd poppler-utils ghostscript
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum ri
#   ruby-dev bundler debhelper gv | postscript-viewer perl-tk xpdf-reader
#   | pdf-viewer texlive-fonts-recommended-doc texlive-latex-base-doc
#   python-pygments icc-profiles libfile-which-perl
#   libspreadsheet-parseexcel-perl texlive-latex-extra-doc
#   texlive-latex-recommended-doc texlive-pstricks dot2tex prerex ruby-tcltk
#   | libtcltk-ruby texlive-pictures-doc vprerex
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-extra texlive-latex-recommended texlive-pictures
#   texlive-plain-generic texlive-xetex tipa
# 0 upgraded, 47 newly installed, 0 to remove and 14 not upgraded.
# Need to get 146 MB of archives.
# After this operation, 460 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lato all 2.0-2 [2,698 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-texgyre all 20160520-1 [8,761 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.13 [5,092 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.13 [2,263 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 rubygems-integration all 1.11 [4,994 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ruby2.5 amd64 2.5.1-1ubuntu1.7 [48.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby amd64 1:2.5.1 [5,712 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rake all 12.3.1-1ubuntu0.1 [44.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-did-you-mean all 1.2.0-2 [9,700 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-minitest all 5.10.3-1 [38.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-power-assert all 0.3.0-1 [7,952 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-test-unit all 3.2.5-1 [61.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libruby2.5 amd64 2.5.1-1ubuntu1.7 [3,068 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 preview-latex-style all 11.91-1ubuntu1 [185 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tex-gyre all 20160520-1 [4,998 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-fonts-recommended all 2017.20180305-1 [5,262 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-recommended all 2017.20180305-1 [14.9 MB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive all 2017.20180305-1 [14.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-pictures all 2017.20180305-1 [4,026 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-latex-extra all 2017.20180305-2 [10.6 MB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-plain-generic all 2017.20180305-2 [23.6 MB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tipa all 2:1.3-20 [2,978 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-xetex all 2017.20180305-1 [10.7 MB]
# Fetched 146 MB in 8s (17.2 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 144865 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package fonts-lato.
# Preparing to unpack .../01-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../02-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../03-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../04-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../05-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../06-fonts-texgyre_20160520-1_all.deb ...
# Unpacking fonts-texgyre (20160520-1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../07-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../08-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../09-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../10-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../11-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../12-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.13_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../13-libgs9_9.26~dfsg+0-0ubuntu0.18.04.13_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../14-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../15-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../16-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../17-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../18-rubygems-integration_1.11_all.deb ...
# Unpacking rubygems-integration (1.11) ...
# Selecting previously unselected package ruby2.5.
# Preparing to unpack .../19-ruby2.5_2.5.1-1ubuntu1.7_amd64.deb ...
# Unpacking ruby2.5 (2.5.1-1ubuntu1.7) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../20-ruby_1%3a2.5.1_amd64.deb ...
# Unpacking ruby (1:2.5.1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../21-rake_12.3.1-1ubuntu0.1_all.deb ...
# Unpacking rake (12.3.1-1ubuntu0.1) ...
# Selecting previously unselected package ruby-did-you-mean.
# Preparing to unpack .../22-ruby-did-you-mean_1.2.0-2_all.deb ...
# Unpacking ruby-did-you-mean (1.2.0-2) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../23-ruby-minitest_5.10.3-1_all.deb ...
# Unpacking ruby-minitest (5.10.3-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../24-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../25-ruby-power-assert_0.3.0-1_all.deb ...
# Unpacking ruby-power-assert (0.3.0-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../26-ruby-test-unit_3.2.5-1_all.deb ...
# Unpacking ruby-test-unit (3.2.5-1) ...
# Selecting previously unselected package libruby2.5:amd64.
# Preparing to unpack .../27-libruby2.5_2.5.1-1ubuntu1.7_amd64.deb ...
# Unpacking libruby2.5:amd64 (2.5.1-1ubuntu1.7) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../28-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../29-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../30-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../31-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../32-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../33-preview-latex-style_11.91-1ubuntu1_all.deb ...
# Unpacking preview-latex-style (11.91-1ubuntu1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../34-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../35-tex-gyre_20160520-1_all.deb ...
# Unpacking tex-gyre (20160520-1) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../36-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../37-texlive-base_2017.20180305-1_all.deb ...
# Unpacking texlive-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../38-texlive-fonts-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-fonts-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../39-texlive-latex-base_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../40-texlive-latex-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive.
# Preparing to unpack .../41-texlive_2017.20180305-1_all.deb ...
# Unpacking texlive (2017.20180305-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../42-texlive-pictures_2017.20180305-1_all.deb ...
# Unpacking texlive-pictures (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../43-texlive-latex-extra_2017.20180305-2_all.deb ...
# Unpacking texlive-latex-extra (2017.20180305-2) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../44-texlive-plain-generic_2017.20180305-2_all.deb ...
# Unpacking texlive-plain-generic (2017.20180305-2) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../45-tipa_2%3a1.3-20_all.deb ...
# Unpacking tipa (2:1.3-20) ...
# Selecting previously unselected package texlive-xetex.
# Preparing to unpack .../46-texlive-xetex_2017.20180305-1_all.deb ...
# Unpacking texlive-xetex (2017.20180305-1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Setting up libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up tex-common (6.09) ...
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up poppler-data (0.4.8-2) ...
# Setting up tex-gyre (20160520-1) ...
# Setting up preview-latex-style (11.91-1ubuntu1) ...
# Setting up fonts-texgyre (20160520-1) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up ruby-did-you-mean (1.2.0-2) ...
# Setting up t1utils (1.41-2) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up rubygems-integration (1.11) ...
# Setting up libpotrace0 (1.14-2) ...
# Setting up javascript-common (11) ...
# Setting up ruby-minitest (5.10.3-1) ...
# Setting up libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Setting up libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up ruby-power-assert (0.3.0-1) ...
# Setting up texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up texlive-base (2017.20180305-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# Setting up texlive-fonts-recommended (2017.20180305-1) ...
# Setting up texlive-plain-generic (2017.20180305-2) ...
# Setting up texlive-latex-base (2017.20180305-1) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up texlive-latex-recommended (2017.20180305-1) ...
# Setting up texlive-pictures (2017.20180305-1) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up texlive (2017.20180305-1) ...
# Setting up texlive-latex-extra (2017.20180305-2) ...
# Setting up texlive-xetex (2017.20180305-1) ...
# Setting up ruby2.5 (2.5.1-1ubuntu1.7) ...
# Setting up ruby (1:2.5.1) ...
# Setting up ruby-test-unit (3.2.5-1) ...
# Setting up rake (12.3.1-1ubuntu0.1) ...
# Setting up libruby2.5:amd64 (2.5.1-1ubuntu1.7) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for tex-common (6.09) ...
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Collecting pypandoc
#   Downloading https://files.pythonhosted.org/packages/d6/b7/5050dc1769c8a93d3ec7c4bd55be161991c94b8b235f88bf7c764449e708/pypandoc-1.5.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pypandoc) (50.3.2)
# Requirement already satisfied: pip>=8.1.0 in /usr/local/lib/python3.6/dist-packages (from pypandoc) (19.3.1)
# Requirement already satisfied: wheel>=0.25.0 in /usr/local/lib/python3.6/dist-packages (from pypandoc) (0.35.1)
# Building wheels for collected packages: pypandoc
#   Building wheel for pypandoc (setup.py) ... done
#   Created wheel for pypandoc: filename=pypandoc-1.5-cp36-none-any.whl size=17038 sha256=93a7ed9651c3f6840afe7f1d9ffe807c209ac0f63c937bcb2588b74575e5f36c
#   Stored in directory: /root/.cache/pip/wheels/bb/7d/d6/2f9af55e800d37e42e546106bcbd36a86e24e725e303d17e04
# Successfully built pypandoc
# Installing collected packages: pypandoc
# Successfully installed pypandoc-1.5

# %%
import subprocess
import time
# Wait for 5 minuts so that colab saves the notebook
time.sleep(5*60)
# !jupyter nbconvert --to HTML "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb"
# !jupyter nbconvert --to PDF "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb"
ipynb_address = path_to_final_project + checkpoint_folder_path
subprocess.call(["mv", "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.html", ipynb_address])
subprocess.call(["mv", "/content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.pdf", ipynb_address])
# Out:
# [NbConvertApp] Converting notebook /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb to HTML
# [NbConvertApp] Writing 529062 bytes to /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.html
# [NbConvertApp] Converting notebook /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.ipynb to PDF
# [NbConvertApp] Writing 201151 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 170884 bytes to /content/drive/Shareddrives/Deep Learning Final Project/fake_comment_generation.pdf
# 0
